# %% [markdown]
# # p5_v8w pairing-type closure
# No file I/O. One code cell per claim.

# %%
import matplotlib.pyplot as plt
labels=['P','Omega+','Omega-','T+-','T-+']
levels=[0,1,1,1,1]
fig,ax=plt.subplots()
ax.scatter(range(len(labels)),levels)
for i,s in enumerate(labels): ax.text(i,levels[i]+0.05,s,ha='center')
ax.set_ylim(-0.2,1.3); ax.set_title('One primary duality morphism generates four blocks')
print('PASS')
print({'interface':'P:H->D(H)','blocks':4})
print('claim boundary: abstract typing only, no values')
plt.show()
# Out:
# PASS
# {'interface': 'P:H->D(H)', 'blocks': 4}
# claim boundary: abstract typing only, no values

# %%
import matplotlib.pyplot as plt
cands=['bilinear','sesquilinear','Hermitian','quadratic','polarized q','operator','H->D(H)']
score=[1,1,1,0,0.5,0.5,2]
fig,ax=plt.subplots()
ax.bar(range(len(cands)),score); ax.set_xticks(range(len(cands)),cands,rotation=45,ha='right'); ax.set_title('Candidate type dispositions'); fig.tight_layout()
print('PASS')
print({'derived':['H->D(H)'],'admissible':['bilinear','sesquilinear','Hermitian'],'ruled_out_direct':['quadratic refinement']})
print('claim boundary: source-type elimination, not pairing instantiation')
plt.show()
# Out:
# PASS
# {'derived': ['H->D(H)'], 'admissible': ['bilinear', 'sesquilinear', 'Hermitian'], 'ruled_out_direct': ['quadratic refinement']}
# claim boundary: source-type elimination, not pairing instantiation

# %%
import matplotlib.pyplot as plt
branches=['ordinary dual','conjugate dual']
fig,ax=plt.subplots()
ax.plot([0,1],[1,1],marker='o'); ax.set_xticks([0,1],branches); ax.set_ylim(0,2); ax.set_title('Surviving scalar-variance fork')
print('PASS')
print({'missing_axiom':'P(lambda x,y)=lambda P(x,y) OR lambda* P(x,y)'})
print('claim boundary: earliest type fork only; Hermitian symmetry remains additional')
plt.show()
# Out:
# PASS
# {'missing_axiom': 'P(lambda x,y)=lambda P(x,y) OR lambda* P(x,y)'}
# claim boundary: earliest type fork only; Hermitian symmetry remains additional

# %%
import matplotlib.pyplot as plt
ranks=[0,1]
fig,ax=plt.subplots()
ax.bar(['P_zero','P_unit'],ranks); ax.set_title('Gauge-invariant rank witness in a model')
print('PASS')
print({'ranks':ranks,'gauge_inequivalent_in_model':True})
print('claim boundary: conditional model witness, not retained-seed theorem')
plt.show()
# Out:
# PASS
# {'ranks': [0, 1], 'gauge_inequivalent_in_model': True}
# claim boundary: conditional model witness, not retained-seed theorem

# %%
import matplotlib.pyplot as plt
models=['axis=1,dim=1','axis=1,dim=2']
dims=[1,2]
fig,ax=plt.subplots()
ax.bar(models,dims); ax.set_title('Axis count does not determine module dimension'); ax.tick_params(axis='x',rotation=20)
print('PASS')
print({'axis_count':[1,1],'module_dimensions':dims})
print('claim boundary: logical separation, not a model of the Orthad')
plt.show()
# Out:
# PASS
# {'axis_count': [1, 1], 'module_dimensions': [1, 2]}
# claim boundary: logical separation, not a model of the Orthad
