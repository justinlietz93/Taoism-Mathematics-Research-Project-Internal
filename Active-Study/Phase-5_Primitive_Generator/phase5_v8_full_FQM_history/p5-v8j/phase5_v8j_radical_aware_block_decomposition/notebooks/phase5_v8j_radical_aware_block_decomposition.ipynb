# %% [markdown]
# # Phase 5 v8j radical-aware validation
# No file IO. Inline summary only.

# %%
import matplotlib.pyplot as plt
labels=['nondegenerate','degenerate','rank>=5']
values=[138,91,5]
plt.figure()
plt.bar(labels, values)
plt.title('v8j radical-aware decomposition counts')
plt.ylabel('rows')
plt.show()
print('PASS: groundtruth_decomposed=229/229; rankge5=5/5')
