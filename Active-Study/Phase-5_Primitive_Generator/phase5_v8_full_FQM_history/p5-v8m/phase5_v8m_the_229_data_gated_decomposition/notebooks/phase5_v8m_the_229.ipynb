# %% [markdown]
# # v8m certificate-gate summary\nGenerated package artifacts contain the executable verifier and CSV outputs. This notebook is intentionally non-IO and records the claim boundaries.

# %%
certificate_rows = 229\nverified = 229\nradical_direct_summand_split_rows = 203\nblocking_rows = 26\nprint({'PASS': verified == certificate_rows, 'verified': verified, 'blocking_rows': blocking_rows})
