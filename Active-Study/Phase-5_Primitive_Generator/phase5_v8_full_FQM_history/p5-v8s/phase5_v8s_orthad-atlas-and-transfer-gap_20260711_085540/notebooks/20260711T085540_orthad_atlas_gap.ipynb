# %% [markdown]
# # p5_v8s typed Orthad gap
# Auxiliary bilinear witness; no package IO.

# %%
import matplotlib.pyplot as plt
P0=[[1,0],[0,1]]
P1=[[1,1],[1,1]]
diag_residual=abs(P0[0][0]-P1[0][0])+abs(P0[1][1]-P1[1][1])
mixed_difference=abs(P0[1][0]-P1[1][0])
plt.figure(figsize=(5,3))
plt.bar(["diagonal residual","mixed difference"],[diag_residual,mixed_difference])
plt.title("Restrictions do not determine transfer")
plt.show()
print({"PASS":diag_residual==0 and mixed_difference==1,"diag_residual":diag_residual,"mixed_difference":mixed_difference})
