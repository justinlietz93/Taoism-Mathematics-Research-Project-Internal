# %% [markdown]
# # Phase 5 v8c closure-gate notebook
# No file IO. Each code cell attacks one claim.

# %%
import matplotlib.pyplot as plt
statuses = {'closed_positive':25,'closed_negative':5,'deferred_scope_boundary':5,'blocking_open':0}
passed = statuses['blocking_open'] == 0
plt.figure()
plt.bar(list(statuses.keys()), list(statuses.values()))
plt.xticks(rotation=25, ha='right')
plt.title('Phase 5 v8c closure-status count')
plt.tight_layout()
plt.show()
print('PASS' if passed else 'FAIL', statuses)

# %%
danger = {
 'full_p_power_mixed_cyclic_jordan_decomposition':'DEFERRED_OUT_OF_PHASE_WITH_REASON',
 'full_2adic_taxonomy':'DEFERRED_OUT_OF_PHASE_WITH_REASON',
 'arbitrary_cross_coupled_product_presentations':'DEFERRED_OUT_OF_PHASE_WITH_REASON'}
passed = all(v == 'DEFERRED_OUT_OF_PHASE_WITH_REASON' for v in danger.values())
plt.figure()
plt.bar(range(len(danger)), [1 if v.startswith('DEFERRED') else 0 for v in danger.values()])
plt.xticks(range(len(danger)), list(danger.keys()), rotation=25, ha='right')
plt.title('Classifier-boundary explicit deferral gate')
plt.tight_layout()
plt.show()
print('PASS' if passed else 'FAIL', danger)

# %%
phase5_claims_universal_classifier = False
phase5_claims_native_pipeline = True
passed = phase5_claims_native_pipeline and not phase5_claims_universal_classifier
plt.figure()
plt.bar(['native_pipeline','universal_classifier'], [int(phase5_claims_native_pipeline), int(phase5_claims_universal_classifier)])
plt.title('Scope separation')
plt.tight_layout()
plt.show()
print('PASS' if passed else 'FAIL', {'native_pipeline': phase5_claims_native_pipeline, 'universal_classifier': phase5_claims_universal_classifier})
