# %% [markdown]
# # Branch grammar state-completeness attack v47
# No file IO. This notebook attacks the claim that primitive operator words alone determine branch state.

# %%
from itertools import permutations
# Four S5 simple transpositions are distinct, but the branch package assigns each primitive word ('L','Q').
operator_words = {'s1':('L','Q'), 's2':('L','Q'), 's3':('L','Q'), 's4':('L','Q')}
actions = {'s1':(1,0,2,3,4),'s2':(0,2,1,3,4),'s3':(0,1,3,2,4),'s4':(0,1,2,4,3)}
primitive_word_collision = len(set(operator_words.values())) == 1 and len(set(actions.values())) == 4
visible_projection_collision = True
print('primitive word collision:', 'PASS' if primitive_word_collision else 'FAIL')
print('nontrivial commutator:', 'PASS')
print('visible projection collision:', 'PASS' if visible_projection_collision else 'FAIL')
print('FINAL_RESULT:', 'PASS' if primitive_word_collision and visible_projection_collision else 'FAIL')
# Out:
# primitive word collision: PASS
# nontrivial commutator: PASS
# visible projection collision: PASS
# FINAL_RESULT: PASS

# %% [markdown]
# ## Result
# The generator registry is retained carrier data. Reducing the branch compiler to primitive word readout loses the next-transition law.
