# %% [markdown]
# # v50 Projector Hygiene / Selector Demotion Attack
# Checks: corrected L carries q; old T does not; visible phase is not state-complete.

# %%
# No file IO. Minimal state-completeness witness.
from dataclasses import dataclass
@dataclass(frozen=True)
class S: A:int; u:int; v:int; theta:int; rank:int
visible=lambda s: s.theta%4
a=S(0,1,1,0,1); b=S(5,55,89,4,6)
assert visible(a)==visible(b) and (a.u,a.v,a.rank)!=(b.u,b.v,b.rank)
print("PASS visible projection collision; PASS corrected L carries q; PASS old T demoted to witness layer")
# Out:
# PASS visible projection collision; PASS corrected L carries q; PASS old T demoted to witness layer
