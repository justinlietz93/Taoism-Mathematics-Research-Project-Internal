# %% [markdown]
# # Phase 4 v4 — Ancient Yi Symbol Mapping
# This notebook audits the symbol-to-carrier mapping tables shipped with the package.

# %%
import csv, json
from pathlib import Path
ROOT = Path.cwd().parent if Path.cwd().name == "notebooks" else Path.cwd()
rows = list(csv.DictReader((ROOT/"outputs"/"phase4_v4_symbol_to_carrier_mapping_table.csv").read_text(encoding="utf-8").splitlines()))
summary = json.loads((ROOT/"outputs"/"phase4_v4_verification_summary.json").read_text())
print(json.dumps(summary, indent=2, ensure_ascii=False))
assert summary["global_pass"]

# %%
import pandas as pd
df = pd.read_csv(ROOT/"outputs"/"phase4_v4_symbol_to_carrier_mapping_table.csv")
display(df.head(8))
print("PASS symbol mapping rows", len(df))
