# %% [markdown]
# # Phase 4 v2 — Modular-B Classification Theorem
#
# Inline audit notebook. No file IO.

# %%
import pandas as pd
import matplotlib.pyplot as plt
rows = [{'domain': 'Phase/Farey B', 'retained_carrier': 'ordered denominator pair q=(u,v)', 'local_refinement': True, 'deterministic': True, 'progress_measure': True, 'finite_completion': True, 'lift_rechart': True, 'projection_loss_witness': True, 'terminal_projection_separated': True, 'primitive_multiplier_or_transition': True, 'classification': 'FULL_MODULAR_B_INSTANCE', 'evidence': 'B(u,v)=sort(v,u+v), uv strictly increases to Delta, L re-charts with q carried, product projection collision included.', 'decisive_failure_if_any': 'none', 'next_falsifier': 'Find admissible q where B is not state-local, uv progress fails before completion, or product-only projection determines B(q).'}, {'domain': 'Ancient Yi octal-place carry', 'retained_carrier': 'LSD-first base-8 digit tuple plus active width', 'local_refinement': True, 'deterministic': True, 'progress_measure': True, 'finite_completion': True, 'lift_rechart': True, 'projection_loss_witness': True, 'terminal_projection_separated': True, 'primitive_multiplier_or_transition': True, 'classification': 'FULL_MODULAR_B_INSTANCE', 'evidence': 'successor/carry increments value; all-7 completion opens a new high place; low digit and scalar projections collide.', 'decisive_failure_if_any': 'none', 'next_falsifier': 'Find source row contradicting LSD-first carry/lift or all-7 completion -> higher-place opening.'}, {'domain': 'Wilhelm six-line ladder', 'retained_carrier': 'six-line carrier plus selected line', 'local_refinement': True, 'deterministic': True, 'progress_measure': False, 'finite_completion': False, 'lift_rechart': False, 'projection_loss_witness': True, 'terminal_projection_separated': True, 'primitive_multiplier_or_transition': True, 'classification': 'CARRIER_TRANSITION_BOUNDARY_NOT_FULL_B', 'evidence': '384 directed single-line transitions close as Q6 custody; no intrinsic completion/lift gate appears in the current extracted transition layer.', 'decisive_failure_if_any': 'no intrinsic completion/lift gate in available source layer', 'next_falsifier': 'Find an intrinsic Wilhelm post-line-6 completion/lift law that upgrades the transition ladder to full Modular-B.'}, {'domain': 'Shadow finite residue/orientation carrier', 'retained_carrier': 'finite quadratic residue/orientation module A_m = Z/(2m)Z', 'local_refinement': False, 'deterministic': True, 'progress_measure': False, 'finite_completion': False, 'lift_rechart': False, 'projection_loss_witness': True, 'terminal_projection_separated': True, 'primitive_multiplier_or_transition': True, 'classification': 'RETAINED_RESIDUE_TRANSFORM_CHANNEL_NOT_B_WITHOUT_REFINEMENT', 'evidence': 'S/T multiplier and orientation-loss gates close, but the channel is a transform carrier rather than a B-refinement system unless a level/refinement operator is supplied.', 'decisive_failure_if_any': 'no intrinsic refinement/completion/lift operator supplied on the residue transform channel', 'next_falsifier': 'Supply or falsify a residue-level refinement/completion/lift operator that turns the transform carrier into full Modular-B.'}, {'domain': 'Product-only Phase quotient', 'retained_carrier': '', 'local_refinement': False, 'deterministic': True, 'progress_measure': False, 'finite_completion': False, 'lift_rechart': False, 'projection_loss_witness': False, 'terminal_projection_separated': False, 'primitive_multiplier_or_transition': False, 'classification': 'REJECTED_QUOTIENT_ONLY_PROJECTION', 'evidence': 'uv alone collides on (1,6) and (2,3) with different B-images.', 'decisive_failure_if_any': 'projection-only state does not carry enough transition data', 'next_falsifier': 'Construct a total G from uv product to next retained pair that agrees with B on all admissible pairs.'}, {'domain': 'Ancient Yi scalar-value quotient', 'retained_carrier': '', 'local_refinement': False, 'deterministic': True, 'progress_measure': False, 'finite_completion': False, 'lift_rechart': False, 'projection_loss_witness': False, 'terminal_projection_separated': False, 'primitive_multiplier_or_transition': False, 'classification': 'REJECTED_QUOTIENT_ONLY_PROJECTION', 'evidence': 'value 0 collides for 0 and 00 with different retained next states because active width is missing.', 'decisive_failure_if_any': 'projection-only state does not carry enough transition data', 'next_falsifier': 'Construct successor on scalar value alone that returns the retained width-correct next carrier.'}, {'domain': 'Wilhelm carrier-only quotient', 'retained_carrier': '', 'local_refinement': False, 'deterministic': True, 'progress_measure': False, 'finite_completion': False, 'lift_rechart': False, 'projection_loss_witness': False, 'terminal_projection_separated': False, 'primitive_multiplier_or_transition': False, 'classification': 'REJECTED_QUOTIENT_ONLY_PROJECTION', 'evidence': 'carrier 111111 collides across selected lines with different targets.', 'decisive_failure_if_any': 'projection-only state does not carry enough transition data', 'next_falsifier': 'Construct a carrier-only transition map that recovers all 384 selected-line events.'}]
df = pd.DataFrame(rows)
df[['domain','classification','local_refinement','progress_measure','finite_completion','lift_rechart','projection_loss_witness']]

# %%
counts = df['classification'].value_counts()
ax = counts.plot(kind='bar', title='Phase 4 v2 classification counts')
ax.set_xlabel('classification')
ax.set_ylabel('count')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()
print('PASS', bool((df['classification'] == 'FULL_MODULAR_B_INSTANCE').sum() == 2))

# %%
witnesses = [{'domain': 'Phase/Farey', 'projection': 'uv product only', 'state_a': '(1,6)', 'state_b': '(2,3)', 'projection_a': 6, 'projection_b': 6, 'next_a': '(6,7)', 'next_b': '(3,5)', 'projection_equal': True, 'next_differs': True, 'gate': 'PASS'}, {'domain': 'Ancient Yi', 'projection': 'low digit only', 'state_a': '7', 'state_b': '77', 'projection_a': 7, 'projection_b': 7, 'next_a': '01', 'next_b': '001', 'projection_equal': True, 'next_differs': True, 'gate': 'PASS'}, {'domain': 'Ancient Yi', 'projection': 'scalar zero only', 'state_a': '0', 'state_b': '00', 'projection_a': 0, 'projection_b': 0, 'next_a': '1', 'next_b': '10', 'projection_equal': True, 'next_differs': True, 'gate': 'PASS'}, {'domain': 'Wilhelm', 'projection': 'carrier bits only', 'state_a': '111111:line1', 'state_b': '111111:line6', 'projection_a': '111111', 'projection_b': '111111', 'next_a': '111110', 'next_b': '011111', 'projection_equal': True, 'next_differs': True, 'gate': 'PASS'}, {'domain': 'Wilhelm', 'projection': 'selected line only', 'state_a': '000000:line3', 'state_b': '111111:line3', 'projection_a': 3, 'projection_b': 3, 'next_a': '000100', 'next_b': '111011', 'projection_equal': True, 'next_differs': True, 'gate': 'PASS'}, {'domain': 'Shadow residue carrier', 'projection': 'scalar bilateral projection', 'state_a': 'positive orientation channel', 'state_b': 'negative orientation channel', 'projection_a': 0, 'projection_b': 0, 'next_a': 'nonzero false-theta readout', 'next_b': 'opposite orientation readout', 'projection_equal': True, 'next_differs': True, 'gate': 'PASS'}]
pd.DataFrame(witnesses)

# %%
print('GLOBAL_PASS:', True)
print('Full Modular-B instances:', list(df.loc[df.classification=='FULL_MODULAR_B_INSTANCE','domain']))
print('Boundary instances:', list(df.loc[df.classification.str.contains('BOUNDARY|RESIDUE', regex=True),'domain']))
