# %% [markdown]
# # Phase 4 v3 — Projection-Loss Formalization
# Finite audit notebook.

# %%
import csv, json
from pathlib import Path
root = Path("..")
rows = list(csv.DictReader(open(root/"outputs/phase4_v3_projection_loss_witnesses.csv")))
summary = {"rows": len(rows), "all_projection_collisions": all(r["proj_x"]==r["proj_y"] for r in rows), "all_next_retained_diverge": all(r["next_x"]!=r["next_y"] for r in rows)}
summary

# %%
import pandas as pd
df = pd.read_csv(root/"outputs/phase4_v3_corpus_instantiations.csv")
df
