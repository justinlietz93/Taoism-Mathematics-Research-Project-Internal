# %% [markdown]
# # Phase 3 v6 audit notebook
# Canon lock + Lean/Lake prep summary.

# %%
import json, pandas as pd
summary=json.load(open('../outputs/phase3_v6_verification_summary.json'))
summary

# %%
pd.read_csv('../outputs/phase3_v6_phase3_claim_registry.csv')

# %%
pd.read_csv('../outputs/phase3_v6_status_matrix.csv')
