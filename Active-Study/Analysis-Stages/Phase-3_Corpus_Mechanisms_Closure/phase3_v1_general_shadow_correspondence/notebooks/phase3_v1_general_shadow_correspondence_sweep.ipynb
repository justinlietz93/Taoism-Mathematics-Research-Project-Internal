# %% [markdown]
# # Phase 3 v1 — General Shadow Correspondence Sweep
#
# This notebook mirrors the script and inspects the generated verification tables.

# %%
import pandas as pd
summary = pd.read_csv('../outputs/phase3_v1_sweep_summary.csv')
summary

# %%
terms = pd.read_csv('../outputs/phase3_v1_coefficient_terms.csv')
terms.head(40)

# %%
general = pd.read_csv('../outputs/phase3_v1_general_vs_specific.csv')
general

# %%
assert summary['case_pass'].all()
print('GLOBAL_PASS')
