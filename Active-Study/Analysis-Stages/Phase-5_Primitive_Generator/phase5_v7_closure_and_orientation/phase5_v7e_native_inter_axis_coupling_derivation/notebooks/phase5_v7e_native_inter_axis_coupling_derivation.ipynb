# %% [markdown]
# # Phase 5 v7e Notebook
# No file IO. Data embedded inline. Each claim cell prints PASS/FAIL and numeric values.

# %%
# Claim 1: shared-boundary cases generate admissible native couplings.
positive = [{'case_id': 'independent_8x8_direct_sum', 'D1': 8, 'D2': 8, 'history_kind': 'independent_axes', 'native_c_mod_lcm': 0, 'well_defined': True, 'expected_behavior': 'direct_sum_zero_cross_term', 'unitarity_residual': 1.070742898624873e-15, 'reversal_residual': 2.04757242619384e-15, 'k4_residual': 4.0951448523876804e-15, 'polarization_residual': 1.2004014554190414e-14, 'representative_invariance_residual': 9.799650315725178e-15, 'pass': True, 'interpretation': 'direct_sum_generated'}, {'case_id': 'shared_8x8_native_c2', 'D1': 8, 'D2': 8, 'history_kind': 'shared_boundary', 'native_c_mod_lcm': 2, 'well_defined': True, 'expected_behavior': 'generated_cross_term', 'unitarity_residual': 2.4570338424181392e-15, 'reversal_residual': 6.542112513837112e-15, 'k4_residual': 1.3084225027674223e-14, 'polarization_residual': 3.234390464888577e-14, 'representative_invariance_residual': 1.1759085194360944e-14, 'pass': True, 'interpretation': 'native_cross_term_generated'}, {'case_id': 'shared_8x12_native_c6', 'D1': 8, 'D2': 12, 'history_kind': 'shared_boundary', 'native_c_mod_lcm': 6, 'well_defined': True, 'expected_behavior': 'generated_cross_term', 'unitarity_residual': 9.866431229634571e-15, 'reversal_residual': 1.1226736090270782e-14, 'k4_residual': 2.2453472180541576e-14, 'polarization_residual': 8.523615710128819e-14, 'representative_invariance_residual': 4.116051206408283e-14, 'pass': True, 'interpretation': 'native_cross_term_generated'}, {'case_id': 'shared_12x12_native_c6', 'D1': 12, 'D2': 12, 'history_kind': 'shared_boundary', 'native_c_mod_lcm': 6, 'well_defined': True, 'expected_behavior': 'generated_cross_term', 'unitarity_residual': 1.3375097754519523e-14, 'reversal_residual': 2.535383424672864e-14, 'k4_residual': 5.0707668493457294e-14, 'polarization_residual': 2.0771842582276985e-13, 'representative_invariance_residual': 6.467868245280473e-14, 'pass': True, 'interpretation': 'native_cross_term_generated'}, {'case_id': 'shared_10x10_native_c2', 'D1': 10, 'D2': 10, 'history_kind': 'shared_boundary', 'native_c_mod_lcm': 2, 'well_defined': True, 'expected_behavior': 'generated_cross_term', 'unitarity_residual': 9.702283772831889e-15, 'reversal_residual': 1.009392089255039e-14, 'k4_residual': 1.897538430072622e-14, 'polarization_residual': 1.18585124327194e-13, 'representative_invariance_residual': 3.283291382988083e-14, 'pass': True, 'interpretation': 'native_cross_term_generated'}, {'case_id': 'shared_16x24_native_c12', 'D1': 16, 'D2': 24, 'history_kind': 'shared_boundary', 'native_c_mod_lcm': 12, 'well_defined': True, 'expected_behavior': 'generated_cross_term', 'unitarity_residual': 1.5357022566237495e-14, 'reversal_residual': 3.4706578070371235e-14, 'k4_residual': 6.940414844788774e-14, 'polarization_residual': 3.17539875105184e-13, 'representative_invariance_residual': 1.1761561116907298e-13, 'pass': True, 'interpretation': 'native_cross_term_generated'}]
passed = all(row['pass'] for row in positive)
print('PASS' if passed else 'FAIL', 'positive cases', sum(row['pass'] for row in positive), '/', len(positive))
print('max residual', max(max(row['unitarity_residual'], row['reversal_residual'], row['k4_residual'], row['polarization_residual'], row['representative_invariance_residual']) for row in positive))
import matplotlib.pyplot as plt
labels=[row['case_id'] for row in positive]
vals=[max(row['unitarity_residual'], row['reversal_residual'], row['k4_residual'], row['polarization_residual'], row['representative_invariance_residual']) for row in positive]
plt.figure(figsize=(8,3)); plt.bar(range(len(vals)), vals); plt.yscale('log'); plt.xticks(range(len(vals)), labels, rotation=80, ha='right'); plt.title('Positive-case max residuals'); plt.tight_layout(); plt.show()

# %%
# Claim 2: negative controls reject stale/invalid generation.
negative = [{'case_id': 'prefix_only_8x12_no_shared_latch', 'D1': 8, 'D2': 12, 'history_kind': 'shared_prefix_only', 'native_c_mod_lcm': 0, 'hand_supplied_c': '', 'well_defined': True, 'expected_behavior': 'must_not_generate_cross_term', 'unitarity_residual': 2.885336381082971e-15, 'reversal_residual': 3.1736322578159106e-15, 'k4_residual': 6.347264515631826e-15, 'polarization_residual': 2.541374226150738e-14, 'representative_invariance_residual': 1.666014831349671e-14, 'pass': True, 'interpretation': 'negative_control_rejected_as_generation'}, {'case_id': 'bad_shared_8x12_native_c3_not_well_defined', 'D1': 8, 'D2': 12, 'history_kind': 'shared_boundary_bad_depth', 'native_c_mod_lcm': 3, 'hand_supplied_c': '', 'well_defined': False, 'expected_behavior': 'fail_representative_invariance', 'unitarity_residual': 0.638441464628368, 'reversal_residual': 1.0, 'k4_residual': 1.4274795425823688, 'polarization_residual': 2.0, 'representative_invariance_residual': 2.0, 'pass': True, 'interpretation': 'negative_control_rejected_as_generation'}, {'case_id': 'bad_shared_12x12_native_c5_degenerate', 'D1': 12, 'D2': 12, 'history_kind': 'shared_boundary_degenerate', 'native_c_mod_lcm': 5, 'hand_supplied_c': '', 'well_defined': True, 'expected_behavior': 'fail_unitarity_degenerate', 'unitarity_residual': 1.0000000000000004, 'reversal_residual': 1.0000000000000004, 'k4_residual': 12.000000000000007, 'polarization_residual': 2.0189295046512254e-13, 'representative_invariance_residual': 7.055946301125838e-14, 'pass': True, 'interpretation': 'negative_control_rejected_as_generation'}, {'case_id': 'bad_shared_10x26_native_c65_degenerate', 'D1': 10, 'D2': 26, 'history_kind': 'shared_boundary_degenerate_mixed', 'native_c_mod_lcm': 65, 'hand_supplied_c': '', 'well_defined': True, 'expected_behavior': 'fail_unitarity_degenerate', 'unitarity_residual': 1.0000000000000004, 'reversal_residual': 1.0000000000000007, 'k4_residual': 2.0000000000000018, 'polarization_residual': 3.6063170052015067e-13, 'representative_invariance_residual': 9.211572259879814e-14, 'pass': True, 'interpretation': 'negative_control_rejected_as_generation'}, {'case_id': 'forbidden_hand_supplied_c6', 'D1': 8, 'D2': 12, 'history_kind': 'hand_supplied_only', 'native_c_mod_lcm': 0, 'hand_supplied_c': 6, 'well_defined': True, 'expected_behavior': 'forbidden_generation_evidence', 'cheat_unitarity_residual': 9.866431229634571e-15, 'cheat_reversal_residual': 1.1226736090270782e-14, 'cheat_k4_residual': 2.2453472180541576e-14, 'cheat_polarization_residual': 8.523615710128819e-14, 'cheat_representative_invariance_residual': 4.116051206408283e-14, 'pass': True, 'interpretation': 'hand_supplied_c_forbidden_native_extraction_zero'}]
passed = all(row['pass'] for row in negative)
print('PASS' if passed else 'FAIL', 'negative controls', sum(row['pass'] for row in negative), '/', len(negative))
import matplotlib.pyplot as plt
labels=[row['case_id'] for row in negative]
vals=[]
for row in negative:
    keys=[k for k in row if k.endswith('_residual')]
    vals.append(max([abs(row[k]) for k in keys] or [0]))
plt.figure(figsize=(8,3)); plt.bar(range(len(vals)), vals); plt.xticks(range(len(vals)), labels, rotation=80, ha='right'); plt.title('Negative-control residual signatures'); plt.tight_layout(); plt.show()

# %%
# Claim 3: nonzero native coupling is not produced by independent/prefix-only histories.
controls = [row for row in negative if row['case_id'] in ['prefix_only_8x12_no_shared_latch','forbidden_hand_supplied_c6']]
passed = all(row['native_c_mod_lcm'] == 0 for row in controls)
print('PASS' if passed else 'FAIL', [(row['case_id'], row['native_c_mod_lcm']) for row in controls])
import matplotlib.pyplot as plt
plt.figure(figsize=(5,3)); plt.bar([row['case_id'] for row in controls],[row['native_c_mod_lcm'] for row in controls]); plt.title('Native c for non-shared/forbidden controls'); plt.xticks(rotation=45, ha='right'); plt.tight_layout(); plt.show()

# %%
# Claim 4: v7e status.
summary = {'phase': 'Phase 5 v7e', 'title': 'Native Inter-Axis Coupling Derivation', 'status': 'NATIVE_SHARED_BOUNDARY_COUPLING_GENERATED_FOR_TESTED_PRODUCT_MODULES_FRONTIER_REFINED', 'global_pass': True, 'phase5_closed': False, 'sealed_before_comparison': True, 'positive_cases': 6, 'positive_cases_passed': 6, 'negative_controls': 5, 'negative_controls_passed': 5, 'max_positive_residual': 3.17539875105184e-13, 'native_extractor': 'shared L-boundary incidence weighted by retained Q-depths before latch', 'core_result': 'Shared-boundary QBL histories generated nonzero admissible c_ij in tested cases; independent/prefix-only histories did not.', 'frontier': 'Derive the full inter-axis coupling registry for arbitrary QBL branching histories and realistic mock-theta finite quadratic modules.'}
print('PASS' if summary['global_pass'] else 'FAIL', summary['status'])
print('frontier:', summary['frontier'])
import matplotlib.pyplot as plt
plt.figure(figsize=(4,3)); plt.bar(['positive','negative'], [summary['positive_cases_passed'], summary['negative_controls_passed']]); plt.title('v7e pass counts'); plt.tight_layout(); plt.show()
