# %% [markdown]
# # Phase 5 v7l Open-Flux Disappearance Revisit

# %%
import json, pathlib
root=pathlib.Path("..")
summary=json.loads((root/"outputs/phase5_v7l_verification_summary.json").read_text())
print("PASS: loaded summary")
print(summary["status"])

# %%
h=summary["hard_numbers"]
assert abs(h["remaining_fraction"]-0.2)<1e-12
assert abs(h["closure_time_hr"]-2.7777777777777777)<1e-6
print("PASS: numeric closure checks")
print(h)
