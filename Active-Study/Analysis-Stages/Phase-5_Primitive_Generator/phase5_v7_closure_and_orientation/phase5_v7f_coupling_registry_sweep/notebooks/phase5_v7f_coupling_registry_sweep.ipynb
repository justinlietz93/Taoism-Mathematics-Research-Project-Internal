# %% [markdown]
# # Phase 5 v7f Coupling Registry Sweep
# No IO notebook. Each code cell embeds data, emits a figure, PASS/FAIL, and numeric results.

# %%
import json, math
import matplotlib.pyplot as plt
summary = json.loads('{"phase": "5_v7f", "title": "Coupling Registry Sweep", "status": "COUPLING_REGISTRY_SWEEP_SUPPORTED_FOR_BOUNDED_SHARED_LATCH_HISTORIES_FRONTIER_REFINED", "global_pass": true, "phase5_closed": false, "D_pair_count": 15, "registry_rows": 918, "unique_generated_c_total": 918, "property_gate_cases": 29, "property_gate_cases_passed": 29, "negative_controls": 23, "negative_controls_passed": 23, "max_positive_residual": 1.0226784664791497e-12, "full_valid_coverage_pairs": 15, "mean_valid_closure_coverage_fraction": 1.0, "mean_admissible_coverage_fraction": 1.0, "sealed_before_comparison": true, "hand_supplied_cij_used_as_generation_evidence": false, "frontier": "bounded shared-latch histories generate many admissible nonzero couplings; complete arbitrary-history registry remains open"}')
labels=['property pass','negative pass']
vals=[summary['property_gate_cases_passed']/summary['property_gate_cases'], summary['negative_controls_passed']/summary['negative_controls']]
plt.figure()
plt.bar(labels, vals)
plt.ylim(0,1.05)
plt.title('v7f pass fractions')
plt.show()
print('PASS' if min(vals) == 1.0 else 'FAIL', vals)

# %%
import json, matplotlib.pyplot as plt
rows=json.loads('[{"D_i": 6, "D_j": 6, "L": 6, "gcd": 6, "admissible_step": 1, "admissible_c_count": 6, "generated_unique_c_count": 6, "generated_admissible_count": 6, "valid_closure_c_count": 1, "generated_valid_closure_c_count": 1, "admissible_coverage_fraction": 1.0, "valid_closure_coverage_fraction": 1.0, "generated_valid_nonzero": "[]", "class_counts": "{\\"cross_degenerate\\": 5, \\"direct_sum_valid\\": 1}"}, {"D_i": 6, "D_j": 10, "L": 30, "gcd": 2, "admissible_step": 15, "admissible_c_count": 2, "generated_unique_c_count": 30, "generated_admissible_count": 2, "valid_closure_c_count": 1, "generated_valid_closure_c_count": 1, "admissible_coverage_fraction": 1.0, "valid_closure_coverage_fraction": 1.0, "generated_valid_nonzero": "[]", "class_counts": "{\\"cross_degenerate\\": 1, \\"direct_sum_valid\\": 1, \\"nonrepresentative\\": 28}"}, {"D_i": 8, "D_j": 8, "L": 8, "gcd": 8, "admissible_step": 1, "admissible_c_count": 8, "generated_unique_c_count": 8, "generated_admissible_count": 8, "valid_closure_c_count": 4, "generated_valid_closure_c_count": 4, "admissible_coverage_fraction": 1.0, "valid_closure_coverage_fraction": 1.0, "generated_valid_nonzero": "[2, 4, 6]", "class_counts": "{\\"cross_degenerate\\": 4, \\"cross_valid_nonzero\\": 3, \\"direct_sum_valid\\": 1}"}, {"D_i": 8, "D_j": 12, "L": 24, "gcd": 4, "admissible_step": 6, "admissible_c_count": 4, "generated_unique_c_count": 24, "generated_admissible_count": 4, "valid_closure_c_count": 4, "generated_valid_closure_c_count": 4, "admissible_coverage_fraction": 1.0, "valid_closure_coverage_fraction": 1.0, "generated_valid_nonzero": "[6, 12, 18]", "class_counts": "{\\"cross_valid_nonzero\\": 3, \\"direct_sum_valid\\": 1, \\"nonrepresentative\\": 20}"}, {"D_i": 8, "D_j": 16, "L": 16, "gcd": 8, "admissible_step": 2, "admissible_c_count": 8, "generated_unique_c_count": 16, "generated_admissible_count": 8, "valid_closure_c_count": 8, "generated_valid_closure_c_count": 8, "admissible_coverage_fraction": 1.0, "valid_closure_coverage_fraction": 1.0, "generated_valid_nonzero": "[2, 4, 6, 8, 10, 12, 14]", "class_counts": "{\\"cross_valid_nonzero\\": 7, \\"direct_sum_valid\\": 1, \\"nonrepresentative\\": 8}"}, {"D_i": 10, "D_j": 10, "L": 10, "gcd": 10, "admissible_step": 1, "admissible_c_count": 10, "generated_unique_c_count": 10, "generated_admissible_count": 10, "valid_closure_c_count": 3, "generated_valid_closure_c_count": 3, "admissible_coverage_fraction": 1.0, "valid_closure_coverage_fraction": 1.0, "generated_valid_nonzero": "[2, 8]", "class_counts": "{\\"cross_degenerate\\": 7, \\"cross_valid_nonzero\\": 2, \\"direct_sum_valid\\": 1}"}, {"D_i": 10, "D_j": 14, "L": 70, "gcd": 2, "admissible_step": 35, "admissible_c_count": 2, "generated_unique_c_count": 70, "generated_admissible_count": 2, "valid_closure_c_count": 1, "generated_valid_closure_c_count": 1, "admissible_coverage_fraction": 1.0, "valid_closure_coverage_fraction": 1.0, "generated_valid_nonzero": "[]", "class_counts": "{\\"cross_degenerate\\": 1, \\"direct_sum_valid\\": 1, \\"nonrepresentative\\": 68}"}, {"D_i": 10, "D_j": 26, "L": 130, "gcd": 2, "admissible_step": 65, "admissible_c_count": 2, "generated_unique_c_count": 130, "generated_admissible_count": 2, "valid_closure_c_count": 1, "generated_valid_closure_c_count": 1, "admissible_coverage_fraction": 1.0, "valid_closure_coverage_fraction": 1.0, "generated_valid_nonzero": "[]", "class_counts": "{\\"cross_degenerate\\": 1, \\"direct_sum_valid\\": 1, \\"nonrepresentative\\": 128}"}, {"D_i": 12, "D_j": 12, "L": 12, "gcd": 12, "admissible_step": 1, "admissible_c_count": 12, "generated_unique_c_count": 12, "generated_admissible_count": 12, "valid_closure_c_count": 2, "generated_valid_closure_c_count": 2, "admissible_coverage_fraction": 1.0, "valid_closure_coverage_fraction": 1.0, "generated_valid_nonzero": "[6]", "class_counts": "{\\"cross_degenerate\\": 10, \\"cross_valid_nonzero\\": 1, \\"direct_sum_valid\\": 1}"}, {"D_i": 12, "D_j": 20, "L": 60, "gcd": 4, "admissible_step": 15, "admissible_c_count": 4, "generated_unique_c_count": 60, "generated_admissible_count": 4, "valid_closure_c_count": 2, "generated_valid_closure_c_count": 2, "admissible_coverage_fraction": 1.0, "valid_closure_coverage_fraction": 1.0, "generated_valid_nonzero": "[30]", "class_counts": "{\\"cross_degenerate\\": 2, \\"cross_valid_nonzero\\": 1, \\"direct_sum_valid\\": 1, \\"nonrepresentative\\": 56}"}]')
labels=[f"{r['D_i']}x{r['D_j']}" for r in rows]
vals=[r['valid_closure_coverage_fraction'] for r in rows]
plt.figure()
plt.bar(labels, vals)
plt.xticks(rotation=45, ha='right')
plt.ylim(0,1.05)
plt.title('Valid closure coverage by pair, sample')
plt.show()
print('PASS', 'min=', min(vals), 'max=', max(vals))

# %%
import json, matplotlib.pyplot as plt
rows=json.loads('[{"D_i": 6, "D_j": 6, "c_native": 0, "unitarity_residual": 9.601696665928266e-16, "K2_reversal_residual": 1.4902628979569743e-15, "K4_identity_residual": 2.1432046931171024e-15, "polarization_residual": 9.20631983979448e-15, "pass": true}, {"D_i": 6, "D_j": 10, "c_native": 0, "unitarity_residual": 1.3322676295501878e-15, "K2_reversal_residual": 1.3378843875962883e-15, "K4_identity_residual": 2.6757687751925766e-15, "polarization_residual": 1.7146117757405692e-14, "pass": true}, {"D_i": 8, "D_j": 8, "c_native": 0, "unitarity_residual": 8.80827594554726e-17, "K2_reversal_residual": 2.361328499809323e-16, "K4_identity_residual": 4.722656999618646e-16, "polarization_residual": 7.230211754182166e-15, "pass": true}, {"D_i": 8, "D_j": 8, "c_native": 2, "unitarity_residual": 8.80827594554726e-17, "K2_reversal_residual": 2.361328499809323e-16, "K4_identity_residual": 4.722656999618646e-16, "polarization_residual": 1.2248943914019886e-14, "pass": true}, {"D_i": 8, "D_j": 8, "c_native": 4, "unitarity_residual": 8.80827594554726e-17, "K2_reversal_residual": 2.361328499809323e-16, "K4_identity_residual": 4.722656999618646e-16, "polarization_residual": 2.4258055516465918e-14, "pass": true}, {"D_i": 8, "D_j": 12, "c_native": 0, "unitarity_residual": 2.996161721955215e-15, "K2_reversal_residual": 1.778683526687357e-15, "K4_identity_residual": 2.896952485406589e-15, "polarization_residual": 2.660745083838722e-14, "pass": true}, {"D_i": 8, "D_j": 12, "c_native": 6, "unitarity_residual": 9.723320091440823e-15, "K2_reversal_residual": 8.740919349386479e-15, "K4_identity_residual": 8.090765726053084e-15, "polarization_residual": 6.953136770440192e-14, "pass": true}, {"D_i": 8, "D_j": 12, "c_native": 12, "unitarity_residual": 7.626444883211555e-15, "K2_reversal_residual": 8.54230062242752e-15, "K4_identity_residual": 1.0803191759374045e-14, "polarization_residual": 1.2355784718849072e-13, "pass": true}, {"D_i": 8, "D_j": 16, "c_native": 0, "unitarity_residual": 1.19646396041099e-16, "K2_reversal_residual": 3.2508870085529316e-16, "K4_identity_residual": 6.501774017105861e-16, "polarization_residual": 1.1069430215407768e-14, "pass": true}, {"D_i": 8, "D_j": 16, "c_native": 2, "unitarity_residual": 1.19646396041099e-16, "K2_reversal_residual": 3.2508870085529316e-16, "K4_identity_residual": 6.501774017105861e-16, "polarization_residual": 2.3473013535589002e-14, "pass": true}, {"D_i": 8, "D_j": 16, "c_native": 4, "unitarity_residual": 1.19646396041099e-16, "K2_reversal_residual": 3.253553710695388e-16, "K4_identity_residual": 6.501774017105861e-16, "polarization_residual": 3.488529071642359e-14, "pass": true}, {"D_i": 10, "D_j": 10, "c_native": 0, "unitarity_residual": 1.781462229187216e-15, "K2_reversal_residual": 2.5009242551780112e-15, "K4_identity_residual": 3.641103736809509e-15, "polarization_residual": 2.0962057393293905e-14, "pass": true}]')
res=[max(r['unitarity_residual'],r['K2_reversal_residual'],r['K4_identity_residual'],r['polarization_residual']) for r in rows]
plt.figure()
plt.plot(range(len(res)), res, marker='o')
plt.yscale('log')
plt.title('Max residual per sampled property gate')
plt.show()
print('PASS' if max(res)<1e-9 else 'FAIL', 'max=', max(res))

# %%
import json, matplotlib.pyplot as plt
rows=json.loads('[{"D_i": 6, "D_j": 6, "c_native": 1, "classification": "cross_degenerate", "pass": true}, {"D_i": 6, "D_j": 10, "c_native": 1, "classification": "nonrepresentative", "pass": true}, {"D_i": 6, "D_j": 10, "c_native": 15, "classification": "cross_degenerate", "pass": true}, {"D_i": 8, "D_j": 8, "c_native": 1, "classification": "cross_degenerate", "pass": true}, {"D_i": 8, "D_j": 12, "c_native": 1, "classification": "nonrepresentative", "pass": true}, {"D_i": 8, "D_j": 16, "c_native": 1, "classification": "nonrepresentative", "pass": true}, {"D_i": 10, "D_j": 10, "c_native": 1, "classification": "cross_degenerate", "pass": true}, {"D_i": 10, "D_j": 14, "c_native": 1, "classification": "nonrepresentative", "pass": true}, {"D_i": 10, "D_j": 14, "c_native": 35, "classification": "cross_degenerate", "pass": true}, {"D_i": 10, "D_j": 26, "c_native": 1, "classification": "nonrepresentative", "pass": true}, {"D_i": 10, "D_j": 26, "c_native": 65, "classification": "cross_degenerate", "pass": true}, {"D_i": 12, "D_j": 12, "c_native": 1, "classification": "cross_degenerate", "pass": true}]')
counts={}
for r in rows: counts[r['classification']]=counts.get(r['classification'],0)+1
plt.figure()
plt.bar(list(counts.keys()), list(counts.values()))
plt.xticks(rotation=30, ha='right')
plt.title('Negative control classes, sample')
plt.show()
print('PASS' if all(r['pass'] for r in rows) else 'FAIL', counts)
