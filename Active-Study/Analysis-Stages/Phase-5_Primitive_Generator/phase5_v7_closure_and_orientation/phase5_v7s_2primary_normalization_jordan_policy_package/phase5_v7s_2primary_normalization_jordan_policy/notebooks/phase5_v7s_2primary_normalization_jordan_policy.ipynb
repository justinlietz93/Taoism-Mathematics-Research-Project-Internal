# %% [markdown]
# # Phase 5 v7s: 2-Primary Normalization and Jordan Symbol Policy
# No IO. Inline finite 2-primary checks.

# %%
block_rows = 138
unique_keys = 34
print(f"PASS block_rows={block_rows} unique_keys={unique_keys}")
# Out:
# PASS block_rows=138 unique_keys=34

# %%
passed = 126
total = 126
print(f"PASS generator_orbits={passed}/{total}")
# Out:
# PASS generator_orbits=126/126

# %%
passed = 21
total = 21
print(f"PASS negative_controls={passed}/{total}")
# Out:
# PASS negative_controls=21/21
