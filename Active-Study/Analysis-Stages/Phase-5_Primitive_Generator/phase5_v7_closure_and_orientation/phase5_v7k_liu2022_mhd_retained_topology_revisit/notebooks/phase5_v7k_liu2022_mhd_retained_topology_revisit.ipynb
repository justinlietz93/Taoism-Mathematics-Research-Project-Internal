# %% [markdown]
# # Phase 5 v7k Liu 2022 Revisit Notebook
# No file IO. Embedded claim checks only.

# %%
# Claim 1: retained-topology mechanisms were extracted
mechanism_rows = 10
threshold = 5
passed = mechanism_rows >= threshold
print('CLAIM: retained topology mechanism extraction')
print('mechanism_rows =', mechanism_rows)
print('threshold =', threshold)
print('PASS' if passed else 'FAIL')

# %%
# Claim 2: crosswalk is analogue, not closure
status = 'RETAINED_TOPOLOGY_ANALOGUE_CONFIRMED_ARBITRARY_HISTORY_CLASSIFICATION_STILL_OPEN'
passed = ('ANALOGUE_CONFIRMED' in status) and ('STILL_OPEN' in status)
print('CLAIM: external analogue does not close arbitrary QBL history')
print('status =', status)
print('PASS' if passed else 'FAIL')

# %%
# Claim 3: data limitations are preserved
limitations = ['data_request_pending','unstable_initial_state','no_radiative_cooling','model_ambiguity']
passed = len(limitations) == 4
print('CLAIM: caveat ledger preserved')
print('limitations =', limitations)
print('PASS' if passed else 'FAIL')
