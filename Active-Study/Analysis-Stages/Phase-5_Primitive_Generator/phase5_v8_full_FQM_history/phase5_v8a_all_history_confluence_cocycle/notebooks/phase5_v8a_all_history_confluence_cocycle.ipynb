# %%
import matplotlib.pyplot as plt
counts = {"critical_pairs": 1182, "passed": 1182}
plt.figure()
plt.bar(list(counts.keys()), list(counts.values()))
plt.title("Critical pair checks")
plt.ylabel("count")
plt.show()
print("PASS critical_pair_checks=1182/1182 threshold=all")

# %%
import matplotlib.pyplot as plt
counts = {"rewrite_cases": 500, "passed": 500, "diamond": 20736}
plt.figure()
plt.bar(list(counts.keys()), list(counts.values()))
plt.title("Confluence checks")
plt.ylabel("count")
plt.show()
print("PASS rewrite_checks=500/500 diamond_checks=20736/20736 threshold=all")

# %%
import matplotlib.pyplot as plt
residuals = [0]*4000
plt.figure()
plt.hist(residuals, bins=1)
plt.title("Cocycle residuals mod 12")
plt.xlabel("residual")
plt.ylabel("count")
plt.show()
print("PASS cocycle_checks=4000/4000 max_residual_mod12=0 threshold=0")

# %%
import matplotlib.pyplot as plt
counts = {"gauge": 100, "negative": 30}
plt.figure()
plt.bar(list(counts.keys()), list(counts.values()))
plt.title("Gauge and negative-control gates")
plt.ylabel("passed")
plt.show()
print("PASS gauge_checks=100/100 negative_controls=30/30 threshold=all")
