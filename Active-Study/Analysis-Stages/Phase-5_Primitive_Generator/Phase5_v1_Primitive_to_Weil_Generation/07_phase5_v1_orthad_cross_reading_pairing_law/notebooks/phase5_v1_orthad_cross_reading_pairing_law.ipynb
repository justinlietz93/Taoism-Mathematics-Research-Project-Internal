# %% [markdown]
# # Phase 5 v1 Orthad Cross-Reading Pairing Law
# Native tables are sealed before Weil comparison.

# %%
from pathlib import Path
import json, pandas as pd
root=Path(".")
print("PASS: package notebook stub; read outputs/*.csv for sealed results")
