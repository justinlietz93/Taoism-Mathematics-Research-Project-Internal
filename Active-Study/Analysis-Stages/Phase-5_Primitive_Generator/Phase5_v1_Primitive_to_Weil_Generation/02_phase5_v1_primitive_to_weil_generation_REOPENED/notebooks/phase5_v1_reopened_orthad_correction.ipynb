# %% [markdown]
# # Phase 5 v1 Reopened Orthad Correction
#
# This notebook attacks the corrected method gates with embedded constants.

# %%
import json
summary = {
    'status':'REOPENED_METHOD_SUSPECT_CORRECTED_TEST_NOT_YET_FORMED',
    'old_verdict':'METHOD_SUSPECT_BARE_PRIMITIVE_CONTROL',
    'corrected_falsifier':'NOT_TRIGGERED',
    'stop_point':'EXPLICIT_QBL_WORD_AND_TERMINAL_ORTHAD_PROJECTION_DECLARATION_GATE'
}
print('PASS: correction status emitted')
print(json.dumps(summary, indent=2))

# %%
gates = {
'orthad_in_loop': True,
'bare_primitive_subtraction_rejected': True,
'symbols_disambiguated': True,
'explicit_W_S_available': False,
'explicit_W_T_available': False,
'native_terminal_projection_available': False,
'corrected_falsifier_triggered': False,
}
assert gates['orthad_in_loop']
assert gates['bare_primitive_subtraction_rejected']
assert gates['symbols_disambiguated']
assert not gates['corrected_falsifier_triggered']
print('PASS: corrected method gates attacked')
print(gates)

# %%
import sympy as sp
N = sp.symbols('N', integer=True, positive=True)
r, s = sp.symbols('r s', integer=True)
Weil_S = sp.exp(-2*sp.pi*sp.I*r*s/N) / sp.sqrt(N)
Weil_T = sp.exp(sp.pi*sp.I*r*r/N)
print('PASS: classical targets remain targets, not grammar macros')
print('Weil_S =', Weil_S)
print('Weil_T =', Weil_T)
