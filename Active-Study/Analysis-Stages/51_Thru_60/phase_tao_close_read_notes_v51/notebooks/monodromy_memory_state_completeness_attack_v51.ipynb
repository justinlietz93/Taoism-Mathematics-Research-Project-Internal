# %% [markdown]
# # v51 Monodromy memory state-completeness attack
# No file I/O. Embedded finite-register checks.

# %%
import sympy as sp
full_empty = sp.Matrix([0, 0])
full_two_turn = sp.Matrix([0, 2])
P = sp.Matrix([[0, 0]])
visible_collision = (P*full_empty)[0] == (P*full_two_turn)[0]
full_changed = (full_empty - full_two_turn) != sp.Matrix([0, 0])
perm_comm = [0,2,4,3,1]
commutator_nonidentity = perm_comm != list(range(5))
checks = {
    'visible_collision': visible_collision,
    'full_register_changed': full_changed,
    'commutator_nonidentity': commutator_nonidentity,
}
print(checks)
print('FINAL_RESULT:', 'PASS' if all(checks.values()) else 'FAIL')
# Out:
# {'visible_collision': True, 'full_register_changed': True, 'commutator_nonidentity': True}
# FINAL_RESULT: PASS
