826864597491403229723364359749415183436491553996529359881593653825629442519718308678951540824183325844045884746598230684751416672062124540392876245684047939604503325', 'pair_product_digits': 459, 'y_A': '1097.7723848325525917575445618123466540273848561454', 'E_A': '-0.22761516744740824245543818765334597261514385460718', 'c_A': 8, 'prefix_length_before_L': 1859, 'commuting_residual': '-8.4836432771029207564e-51'}, {'A': 7, 'N_A': 768, 'J_A': 1530, 'm_A': 3060, 'Q_cumulative': 1522, 'T_A': 2205, 'pair_u': '...', 'pair_v': '...', 'pair_product_digits': 922, 'y_A': '2204.0150142693959676430241134958260543155928377267', 'E_A': '-0.98498573060403235697588650417394568440716227325211', 'c_A': 9, 'prefix_length_before_L': 3734, 'commuting_residual': '1.5163567228970792436e-51'}, {'A': 8, 'N_A': 1536, 'J_A': 3066, 'm_A': 6132, 'Q_cumulative': 3057, 'T_A': 4417, 'pair_u': '...', 'pair_v': '...', 'pair_product_digits': 1847, 'y_A': '4416.5002731430827194139832168627848548920088008895', 'E_A': '-0.49972685691728058601678313721514510799119911054197', 'c_A': 7, 'prefix_length_before_L': 7482, 'commuting_residual': '1.5163567228970792436e-51'}]
CONSTANTS = {'phi': '1.6180339887498948482045868343656381177203091798057628621354486227052604628189024', 'lambda': '1.4404200904125564790175514995878638024586041426840560816454417295665132843529904', 'beta': '0.17227593818455474617031912639443655392849942014208800622937327447832330629149551', 'gamma': '8.4702446042907841279349898711327462608231254359622484836432771029207563998264467'}

b = sp.symbols('b', integer=True, nonnegative=True)
# Inductive algebra: B(F_(b+1),F_(b+2)) = (F_(b+2),F_(b+3)).
identity = sp.Eq(sp.Function('F')(b+1) + sp.Function('F')(b+2), sp.Function('F')(b+3))
vals = []
a0, a1 = 0, 1
F = [a0, a1]
for _ in range(30): F.append(F[-1] + F[-2])
for n in range(10): vals.append((n, F[n+1], F[n+2]))
passed = all(vals[n+1][1:] == (vals[n][2], vals[n][1] + vals[n][2]) for n in range(9))
print('Exact inductive target:', identity)
print('Finite regression rows:', vals)
print('PASS' if passed else 'FAIL')
fig, ax = plt.subplots()
ax.plot([v[0] for v in vals], [v[1] for v in vals], marker='o')
ax.set_title('Fibonacci corridor first coordinate')
ax.set_xlabel('primitive B count b'); ax.set_ylabel('F_(b+1)')
plt.show()
# Out:
# Exact inductive target: Eq(F(b + 1) + F(b + 2), F(b + 3))
# Finite regression rows: [(0, 1, 1), (1, 1, 2), (2, 2, 3), (3, 3, 5), (4, 5, 8), (5, 8, 13), (6, 13, 21), (7, 21, 34), (8, 34, 55), (9, 55, 89)]
# PASS

# %% [markdown]
# ## Claim 2: capacity/exponent identity

# %%
import sympy as sp
import matplotlib.pyplot as plt
, 'pair_u': '...', 'pair_v': '...', 'pair_product_digits': 922, 'y_A': '2204.0150142693959676430241134958260543155928377267', 'E_A': '-0.98498573060403235697588650417394568440716227325211', 'c_A': 9, 'prefix_length_before_L': 3734, 'commuting_residual': '1.5163567228970792436e-51'}, {'A': 8, 'N_A': 1536, 'J_A': 3066, 'm_A': 6132, 'Q_cumulative': 3057, 'T_A': 4417, 'pair_u': '...', 'pair_v': '...', 'pair_product_digits': 1847, 'y_A': '4416.5002731430827194139832168627848548920088008895', 'E_A': '-0.49972685691728058601678313721514510799119911054197', 'c_A': 7, 'prefix_length_before_L': 7482, 'commuting_residual': '1.5163567228970792436e-51'}]
CONSTANTS = {'phi': '1.6180339887498948482045868343656381177203091798057628621354486227052604628189024', 'lambda': '1.4404200904125564790175514995878638024586041426840560816454417295665132843529904', 'beta': '0.17227593818455474617031912639443655392849942014208800622937327447832330629149551', 'gamma': '8.4702446042907841279349898711327462608231254359622484836432771029207563998264467'}

A = sp.symbols('A', integer=True, nonnegative=True)
J = 6*(2**(A+1)-1)
m = 12*(2**(A+1)-1)
result = sp.simplify(m-2*J)
passed = result == 0
print('Exact symbolic result m_A-2J_A =', result)
print('Exact recurrence J_(A+1)-(2J_A+6) =', sp.simplify(6*(2**(A+2)-1)-(2*J+6)))
print('PASS' if passed else 'FAIL')
fig, ax = plt.subplots()
xs = list(range(8)); ax.plot(xs, [6*(2**(x+1)-1) for x in xs], marker='o')
ax.set_title('Carried boundary position J_A'); ax.set_xlabel('A'); ax.set_ylabel('J_A')
plt.show()
# Out:
# Exact symbolic result m_A-2J_A = 0
# Exact recurrence J_(A+1)-(2J_A+6) = 0
# PASS

# %% [markdown]
# ## Claim 3: cumulative B count is state-recoverable

# %%
import sympy as sp
import matplotlib.pyplot as plt
ROWS = [{'A': 0, 'N_A': 6, 'J_A': 6, 'm_A': 12, 'Q_cumulative': 5, 'T_A': 9, 'pair_u': '55', 'pair_v': '89', 'pair_product_digits': 4, 'y_A': '8.8147964806598936202756281239216193686801242762464', 'E_A': '-0.18520351934010637972437187607838063131987572375358', 'c_A': None, 'prefix_length_before_L': 14, 'commuting_residual': None}, {'A': 1, 'N_A': 12, 'J_A': 18, 'm_A': 36, 'Q_cumulative': 16, 'T_A': 27, 'pair_u': '317811', 'pair_v': '514229', 'pair_product_digits': 12, 'y_A': '26.099837565610571368486246118975984998183373988455', 'E_A': '-0.9001624343894286315137538810240150018166260115449', 'c_A': 9, 'prefix_length_before_L': 44, 'commuting_residual': '1.1516356722897079244e-50'}, {'A': 2, 'N_A': 24, 'J_A': 42, 'm_A': 84, 'Q_cumulative': 39, 'T_A': 61, 'pair_u': '4052739537881', 'pair_v': '6557470319842', 'pair_product_digits': 26, 'y_A': '60.669919735511926864907482109084716257189873412872', 'E_A': '-0.33008026448807313509251789091528374281012658712756', 'c_A': 7, 'prefix_length_before_L': 102, 'commuting_residual': '-8.4836432771029207564e-51'}, {'A': 3, 'N_A': 48, 'J_A': 90, 'm_A':
# q_A is exactly the Fibonacci pair indexed by T_A; uniqueness is corridor-internal.
triples = [(r['A'], r['T_A'], int(r['pair_u']), int(r['pair_v'])) for r in ROWS]
passed = len({(u,v) for _,_,u,v in triples}) == len(triples)
print('Boundary (A,T_A,q_A) rows:', triples[:7])
print('Pair-to-index uniqueness on injected reachable rows:', passed)
print('Universal theorem source: induction in research document / Lean surface.')
print('PASS' if passed else 'FAIL')
fig, ax = plt.subplots()
ax.plot([x[0] for x in triples], [x[1] for x in triples], marker='o')
ax.set_title('Cumulative B count T_A'); ax.set_xlabel('A'); ax.set_ylabel('T_A')
plt.show()
# Out:
# Boundary (A,T_A,q_A) rows: [(0, 9, 55, 89), (1, 27, 317811, 514229), (2, 61, 4052739537881, 6557470319842), (3, 130, 1066340417491710595814572169, 1725375039079340637797070384), (4, 269, 119447720249892581203851665820676436622934188700177088360, 193270471243015279782059101964580241188515112465021394429), (5, 545, 572488245870673344662194682459267086009989015536025670856161416248139175446894290669084306226748539738437927821528, 926305439978556110345168148279287821152865667970711489644302195807201560695593260839033495142464219140896452459573), (6, 1098, 21278040567621240190250096573155104972042275846793500076213962089840238578679717839125802288137532091430266033909453459192344331814384442833488318831899600435373589206725797621603635102375685791787722756398203081436561096758124901, 3442859285241027194008361307091963063578189472401787439654596429282686459749140322972336435974941518343649155399652935988159365382562944251971830867895154082418332584404588474659823068475141667206212454039287
# ...

# %% [markdown]
# ## Claim 4: internal factor formula

# %%
import sympy as sp
import matplotlib.pyplot as plt
ROWS = [{'A': 0, 'N_A': 6, 'J_A': 6, 'm_A': 12, 'Q_cumulative': 5, 'T_A': 9, 'pair_u': '55', 'pair_v': '89', 'pair_product_digits': 4, 'y_A': '8.8147964806598936202756281239216193686801242762464', 'E_A': '-0.18520351934010637972437187607838063131987572375358', 'c_A': None, 'prefix_length_before_L': 14, 'commuting_residual': None}, {'A': 1, 'N_A': 12, 'J_A': 18, 'm_A': 36, 'Q_cumulative': 16, 'T_A': 27, 'pair_u': '317811', 'pair_v': '514229', 'pair_product_digits': 12, 'y_A': '26.099837565610571368486246118975984998183373988455', 'E_A': '-0.9001624343894286315137538810240150018166260115449', 'c_A': 9, 'prefix_length_before_L': 44, 'commuting_residual': '1.1516356722897079244e-50'}, {'A': 2, 'N_A': 24, 'J_A': 42, 'm_A': 84, 'Q_cumulative': 39, 'T_A': 61, 'pair_u': '4052739537881', 'pair_v': '6557470319842', 'pair_product_digits': 26, 'y_A': '60.669919735511926864907482109084716257189873412872', 'E_A': '-0.33008026448807313509251789091528374281012658712756', 'c_A': 7, 'prefix_length_before_L': 102, 'commuting_residual': '-8.4836432771029207564e-51'}, {'A': 3, 'N_A': 48, 'J_A': 90, 'm_A': 180, 'Q_cumulative': 86, 'T_A': 130, 'pair_u': '1066340417491710595814572169', 'pair_v': '1725375039079340637797070384', 'pair_product_digits': 55, 'y_A': '
pi = lam*j + beta - b
print('Exact factor coordinate:', pi)
# Numerical witnesses use injected state coordinates, not an A-only lookup inside pi.
errs = [float(r['E_A']) for r in ROWS]
passed = all(-1 < e < 0 for e in errs)
print('Witness range:', min(errs), max(errs))
print('PASS' if passed else 'FAIL')
fig, ax = plt.subplots()
ax.plot([r['A'] for r in ROWS], errs, marker='o')
ax.set_title('State-internal factor E_A'); ax.set_xlabel('A'); ax.set_ylabel('E_A')
plt.show()
# Out:
# Exact factor coordinate: -b + beta + j*lambda
# Witness range: -0.9849857306040324 -0.18520351934010637
# PASS

# %% [markdown]
# ## Claim 5: commuting factor law

# %%
import sympy as sp
import matplotlib.pyplot as plt
ROWS = [{'A': 0, 'N_A': 6, 'J_A': 6, 'm_A': 12, 'Q_cumulative': 5, 'T_A': 9, 'pair_u': '55', 'pair_v': '89', 'pair_product_digits': 4, 'y_A': '8.8147964806598936202756281239216193686801242762464', 'E_A': '-0.18520351934010637972437187607838063131987572375358', 'c_A': None, 'prefix_length_before_L': 14, 'commuting_residual': None}, {'A': 1, 'N_A': 12, 'J_A': 18, 'm_A': 36, 'Q_cumulative': 16, 'T_A': 27, 'pair_u': '317811', 'pair_v': '514229', 'pair_product_digits': 12, 'y_A': '26.099837565610571368486246118975984998183373988455', 'E_A': '-0.9001624343894286315137538810240150018166260115449', 'c_A': 9, 'prefix_length_before_L': 44, 'commuting_residual': '1.1516356722897079244e-50'}, {'A': 2, 'N_A': 24, 'J_A': 42, 'm_A': 84, 'Q_cumulative': 39, 'T_A': 61, 'pair_u': '4052739537881', 'pair_v': '6557470319842', 'pair_product_digits': 26, 'y_A': '60.669919735511926864907482109084716257189873412872', 'E_A': '-0.33008026448807313509251789091528374281012658712756', 'c_A': 7, 'prefix_length_before_L': 102, 'commuting_residual': '-8.4836432771029207564e-51'}, {'A': 3, 'N_A': 48, 'J_A': 90, 'm_A': 180, 'Q_cumulative': 86, 'T_A': 130, 'pair_u': '1066340417491710595814572169', 'pair_v': '1725375039079340637797070384', 'pair_product_digits': 55, 'y_A': '129.81008407531463785774995408930217877520287226171', 'E_A': '-0.18991592468536214225004591069782122479712773829286', 'c_A': 8, 'prefix_length_before_L': 219, 'commuting_residual': '1.1516356722897079244e-50'}, {'A': 4, 'N_A': 96, 'J_A': 186, 'm_A': 372, 'Q_cumulative': 181, 'T_A': 269, 'pair_u': '119447720249892581203851665820676436622934188700177088360', 'pair_v': '193270471243015279782059101964580241188515112465021394429', 'pair_product_digits': 113, 'y_A': '268.09041275492005984343489804973710381122886995938', 'E_A': '-0.90958724507994015656510195026289618877113004062348', 'c_A': 9, 'prefix_length_before_L': 454, 'commuting_residual': '-8.4836432771029207564e-51'}, {'A': 5, 'N_A': 192, 'J_A': 378, 'm_A': 756, 'Q_cumulative': 372, 'T_A': 545, 'pair_u': '572488245870673344662194682459267086009989015536025670856161416248139175446894290669084306226748539738437927821528', 'pair_v': '926305439978556110345168148279287821152865667970711489644302195807201560695593260839033495142464219140896452459573', 'pair_product_digits': 228, 'y_A': '544.65107011413090381480478597060695388328086535472', 'E_A': '-0.34892988586909618519521402939304611671913464528471', 'c_A': 7, 'prefix_length_before_L': 922, 'commuting_residual': '1.5163567228970792436e-51'}, {'A': 6, 'N_A': 384, 'J_A': 762, 'm_A': 1524, 'Q_cumulative': 755, 'T_A': 1098, 'pair_u': '21278040567621240190250096573155104972042275846793500076213962089840238578679717839125802288137532091430266033909453459192344331814384442833488318831899600435373589206725797621603635102375685791787722756398203081436561096758124901', 'pair_v': '34428592852410271940083613070919630635781894724017874396545964292826864597491403229723364359749415183436491553996529359881593653825629442519718308678951540824183325844045884746598230684751416672062124540392876245684047939604503325', 'pair_product_digits': 459, 'y_A': '1097.7723848325525917575445618123466540273848561454', 'E_A': '-0.22761516744740824245543818765334597261514385460718', 'c_A': 8, 'prefix_length_before_L': 1859, 'commuting_residual': '-8.4836432771029207564e-51'}, {'A': 7, 'N_A': 768, 'J_A': 1530, 'm_A': 3060, 'Q_cumulative': 1522, 'T_A': 2205, 'pair_u': '...', 'pair_v': '...', 'pair_product_digits': 922, 'y_A': '2204.0150142693959676430241134958260543155928377267', 'E_A': '-0.98498573060403235697588650417394568440716227325211', 'c_A': 9, 'prefix_length_before_L': 3734, 'commuting_residual': '1.5163567228970792436e-51'}, {'A': 8, 'N_A': 1536, 'J_A': 3066, 'm_A': 6132, 'Q_cumulative': 3057, 'T_A': 4417, 'pair_u': '...', 'pair_v': '...', 'pair_product_digits': 1847, 'y_A': '4416.5002731430827194139832168627848548920088008895', 'E_A': '-0.49972685691728058601678313721514510799119911054197', 'c_A': 7, 'prefix_length_before_L': 7482, 'commuting_residual': '1.5163567228970792436e-51'}]
CONSTANTS = {'phi': '1.6180339887498948482045868343656381177203091798057628621354486227052604628189024', 'lambda': '1.4404200904125564790175514995878638024586041426840560816454417295665132843529904', 'beta': '0.17227593818455474617031912639443655392849942014208800622937327447832330629149551', 'gamma': '8.4702446042907841279349898711327462608231254359622484836432771029207563998264467'}

lam, beta, j, b, c = sp.symbols('lambda beta j b c', real=True)
gamma = 6*lam-beta
lhs = lam*(2*j+6)+beta-(2*b+c)
rhs = 2*(lam*j+beta-b)+gamma-c
result = sp.simplify(lhs-rhs)
resids = [r['commuting_residual'] for r in ROWS[1:]]
passed = result == 0 and all(abs(float(x)) < 1e-15 for x in resids)
print('Exact symbolic residual:', result)
print('Finite numeric residuals:', resids)
print('PASS' if passed else 'FAIL')
fig, ax = plt.subplots()
ax.plot([r['A'] for r in ROWS[1:]], [abs(float(x)) for x in resids], marker='o')
ax.set_title('Boundary factor commuting residual'); ax.set_xlabel('A'); ax.set_ylabel('|residual|')
plt.show()
# Out:
# Exact symbolic residual: 0
# Finite numeric residuals: ['1.1516356722897079244e-50', '-8.4836432771029207564e-51', '1.1516356722897079244e-50', '-8.4836432771029207564e-51', '1.5163567228970792436e-51', '-8.4836432771029207564e-51', '1.5163567228970792436e-51', '1.5163567228970792436e-51']
# PASS

359749415183436491553996529359881593653825629442519718308678951540824183325844045884746598230684751416672062124540392876245684047939604503325', 'pair_product_digits': 459, 'y_A': '1097.7723848325525917575445618123466540273848561454', 'E_A': '-0.22761516744740824245543818765334597261514385460718', 'c_A': 8, 'prefix_length_before_L': 1859, 'commuting_residual': '-8.4836432771029207564e-51'}, {'A': 7, 'N_A': 768, 'J_A': 1530, 'm_A': 3060, 'Q_cumulative': 1522, 'T_A': 2205, 'pair_u': '...', 'pair_v': '...', 'pair_product_digits': 922, 'y_A': '2204.0150142693959676430241134958260543155928377267', 'E_A': '-0.98498573060403235697588650417394568440716227325211', 'c_A': 9, 'prefix_length_before_L': 3734, 'commuting_residual': '1.5163567228970792436e-51'}, {'A': 8, 'N_A': 1536, 'J_A': 3066, 'm_A': 6132, 'Q_cumulative': 3057, 'T_A': 4417, 'pair_u': '...', 'pair_v': '...', 'pair_product_digits': 1847, 'y_A': '4416.5002731430827194139832168627848548920088008895', 'E_A': '-0.49972685691728058601678313721514510799119911054197', 'c_A': 7, 'prefix_length_before_L': 7482, 'commuting_residual': '1.5163567228970792436e-51'}]
CONSTANTS = {'phi': '1.6180339887498948482045868343656381177203091798057628621354486227052604628189024', 'lambda': '1.4404200904125564790175514995878638024586041426840560816454417295665132843529904', 'beta': '0.17227593818455474617031912639443655392849942014208800622937327447832330629149551', 'gamma': '8.4702446042907841279349898711327462608231254359622484836432771029207563998264467'}

carries = [r['c_A'] for r in ROWS if r['c_A'] is not None]
passed = set(carries).issubset({7,8,9})
print('Injected carries:', carries)
print('Alphabet:', sorted(set(carries)))
print('Universal source: global ceiling bridge plus E in (-1,0).')
print('PASS' if passed else 'FAIL')
fig, ax = plt.subplots()
ax.step(list(range(1,len(carries)+1)), carries, where='mid')
ax.set_title('Boundary carry word'); ax.set_xlabel('A'); ax.set_ylabel('c_A')
plt.show()
# Out:
# Injected carries: [9, 7, 8, 9, 7, 8, 9, 7]
# Alphabet: [7, 8, 9]
# Universal source: global ceiling bridge plus E in (-1,0).
# PASS

# %% [markdown]
# ## Claim 7: negative control, j-only projection fails

# %%
import sympy as sp
import matplotlib.pyplot as plt
ROWS = [{'A': 0, 'N_A': 6, 'J_A': 6, 'm_A': 12, 'Q_cumulative': 5, 'T_A': 9, 'pair_u': '55', 'pair_v': '89', 'pair_product_digits': 4, 'y_A': '8.8147964806598936202756281239216193686801242762464', 'E_A': '-0.18520351934010637972437187607838063131987572375358', 'c_A': None, 'prefix_length_before_L': 14, 'commuting_residual': None}, {'A': 1, 'N_A': 12, 'J_A': 18, 'm_A': 36, 'Q_cumulative': 16, 'T_A': 27, 'pair_u': '317811', 'pair_v': '514229', 'pair_product_digits': 12, 'y_A': '26.099837565610571368486246118975984998183373988455', 'E_A': '-0.9001624343894286315137538810240150018166260115449', 'c_A': 9, 'prefix_length_before_L': 44, 'commuting_residual': '1.1516356722897079244e-50'}, {'A': 2, 'N_A': 24, 'J_A': 42, 'm_A': 84, 'Q_cumulative': 39, 'T_A': 
CONSTANTS = {'phi': '1.6180339887498948482045868343656381177203091798057628621354486227052604628189024', 'lambda': '1.4404200904125564790175514995878638024586041426840560816454417295665132843529904', 'beta': '0.17227593818455474617031912639443655392849942014208800622937327447832330629149551', 'gamma': '8.4702446042907841279349898711327462608231254359622484836432771029207563998264467'}

lam, beta, j, c = sp.symbols('lambda beta j c', real=True)
pi0 = lam*j+beta
jnext = 2*j+6
residual = sp.expand((lam*jnext+beta) - (2*pi0+(6*lam-beta)-c))
passed = sp.simplify(residual-c) == 0 and residual != 0
print('Exact residual after deleting retained B index:', residual)
print('The missing term is exactly the carry c.')
print('PASS' if passed else 'FAIL')
fig, ax = plt.subplots()
cs = [7,8,9]; ax.bar([str(x) for x in cs], cs)
ax.set_title('j-only factor residual'); ax.set_xlabel('carry'); ax.set_ylabel('residual')
plt.show()
# Out:
# Exact residual after deleting retained B index: c
# The missing term is exactly the carry c.
# PASS

# %% [markdown]
# ## Claim 8: alphabet roles are not symbolwise

# %%
import sympy as sp
import matplotlib.pyplot as plt
ROWS = [{'A': 0, 'N_A': 6, 'J_A': 6, 'm_A': 12, 'Q_cumulative': 5, 'T_A': 9, 'pair_u': '55', 'pair_v': '89', 'pair_product_digits': 4, 'y_A': '8.8147964806598936202756281239216193686801242762464', 'E_A': '-0.18520351934010637972437187607838063131987572375358', 'c_A': None, 'prefix_length_before_L': 14, 'commuting_residual': None}, {'A': 1, 'N_A': 12, 'J_A': 18, 'm_A': 36, 'Q_cumulative': 16, 'T_A': 27, 'pair_u': '317811', 'pair_v': '514229', 'pair_product_digits': 12, 'y_A': '26.099837565610571368486246118975984998183373988455', 'E_A': '-0.9001624343894286315137538810240150018166260115449', 'c_A': 9, 'prefix_length_before_L': 44, 'commuting_residual': '1.1516356722897079244e-50'}, {'A': 2, 'N_A': 24, 'J_A': 42, 'm_A': 84, 'Q_cumulative': 39, 'T_A': 61, 'pair_u': '4052739537881', 'pair_v': '6557470319842', 'pair_product_digits': 26, 'y_A': '60.669919735511926864907482109084716257189873412872', 'E_A': '-0.33008026448807313509251789091528374281012658712756', 'c_A': 7, 'prefix_length_before_L': 102, 'commuting_residual': '-8.4836432771029207564e-51'}, {'A': 3, 'N_A': 48, 'J_A': 90, 'm_A': 180, 'Q_cumulative': 86, 'T_A': 130, 'pair_u': '1066340417491710595814572169', 'pair_v': '1725375039079340637797070384', 'pair_product_digits': 55, 'y_A': '129.81008407531463785774995408930217877520287226171', 'E_A': '-0.18991592468536214225004591069782122479712773829286', 'c_A': 8, 'prefix_length_before_L': 219, 'commuting_residual': '1.1516356722897079244e-50'}, {'A': 4, 'N_A': 96, 'J_A': 186, 'm_A': 372, 'Q_cumulative': 181, 'T_A': 269, 'pair_u': '119447720249892581203851665820676436622934188700177088360', 'pair_v': '193270471243015279782059101964580241188515112465021394429', 'pair_product_digits': 113, 'y_A': '268.09041275492005984343489804973710381122886995938', 'E_A': '-0.90958724507994015656510195026289618877113004062348', 'c_A': 9, 'prefix_length_before_L': 454, 'commuting_residual': '-8.4836432771029207564e-51'}, {'A': 5, 'N_A': 192, 'J_A': 378, 'm_A': 756, 'Q_cumulative': 372, 'T_A': 545, 'pair_u': '572488245870673344662194682459267086009989015536025670856161416248139175446894290669084306226748539738437927821528', 'pair_v': '926305439978556110345168148279287821152865667970711489644302195807201560695593260839033495142464219140896452459573', 'pair_product_digits': 228, 'y_A': '544.65107011413090381480478597060695388328086535472', 'E_A': '-0.34892988586909618519521402939304611671913464528471', 'c_A': 7, 'prefix_length_before_L': 922, 'commuting_residual': '1.5163567228970792436e-51'}, {'A': 6, 'N_A': 384, 'J_A': 762, 'm_A': 1524, 'Q_cumulative': 755, 'T_A': 1098, 'pair_u': '21278040567621240190250096573155104972042275846793500076213962089840238578679717839125802288137532091430266033909453459192344331814384442833488318831899600435373589206725797621603635102375685791787722756398203081436561096758124901', 'pair_v': '34428592852410271940083613070919630635781894724017874396545964292826864597491403229723364359749415183436491553996529359881593653825629442519718308678951540824183325844045884746598230684751416672062124540392876245684047939604503325', 'pair_product_digits': 459, 'y_A': '1097.7723848325525917575445618123466540273848561454', 'E_A': '-0.22761516744740824245543818765334597261514385460718', 'c_A': 8, 'prefix_length_before_L': 1859, 'commuting_residual': '-8.4836432771029207564e-51'}, {'A': 7, 'N_A': 768, 'J_A': 1530, 'm_A': 3060, 'Q_cumulative': 1522, 'T_A': 2205, 'pair_u': '...', 'pair_v': '...', 'pair_product_digits': 922, 'y_A': '2204.0150142693959676430241134958260543155928377267', 'E_A': '-0.98498573060403235697588650417394568440716227325211', 'c_A': 9, 'prefix_length_before_L': 3734, 'commuting_residual': '1.5163567228970792436e-51'}, {'A': 8, 'N_A': 1536, 'J_A': 3066, 'm_A': 6132, 'Q_cumulative': 3057, 'T_A': 4417, 'pair_u': '...', 'pair_v': '...', 'pair_product_digits': 1847, 'y_A': '4416.5002731430827194139832168627848548920088008895', 'E_A': '-0.49972685691728058601678313721514510799119911054197', 'c_A': 7, 'prefix_length_before_L': 7482, 'commuting_residual': '1.5163567228970792436e-51'}]
CONSTANTS = {'phi': '1.6180339887498948482045868343656381177203091798057628621354486227052604628189024', 'lambda': '1.4404200904125564790175514995878638024586041426840560816454417295665132843529904', 'beta': '0.17227593818455474617031912639443655392849942014208800622937327447832330629149551', 'gamma': '8.4702446042907841279349898711327462608231254359622484836432771029207563998264467'}

primitive = {'B':'pair refinement','Q':'phase-position advance','L':'domain/rank extension'}
carry = {'7':'boundary count cocycle','8':'boundary count cocycle','9':'boundary count cocycle'}
passed = len(primitive)==len(carry) and len(set(primitive.values()))==3 and len(set(carry.values()))==1
print('Primitive roles:', primitive)
print('Carry roles:', carry)
print('Equal cardinality does not preserve role or time scale.')
print('PASS' if passed else 'FAIL')
fig, ax = plt.subplots()
ax.bar(['primitive role types','carry role types'], [len(set(primitive.values())),len(set(carry.values()))])
ax.set_title('Role diversity, not alphabet size'); ax.set_ylabel('distinct operational roles')
plt.show()
# Out:
# Primitive roles: {'B': 'pair refinement', 'Q': 'phase-position advance', 'L': 'domain/rank extension'}
# Carry roles: {'7': 'boundary count cocycle', '8': 'boundary count cocycle', '9': 'boundary count cocycle'}
# Equal cardinality does not preserve role or time scale.
# PASS

# %% [markdown]
# ## Claim 9: five-valued defect is a difference factor

# %%
import sympy as sp
import matplotlib.pyplot as plt
ROWS = [{'A': 0, 'N_A': 6, 'J_A': 6, 'm_A': 12, 'Q_cumulative': 5, 'T_A': 9, 'pair_u': '55', 'pair_v': '89', 'pair_product_digits': 4, 'y_A': '8.8147964806598936202756281239216193686801242762464', 'E_A': '-0.18520351934010637972437187607838063131987572375358', 'c_A': None, 'prefix_length_before_L': 14, 'commuting_residual': None}, {'A': 1, 'N_A': 12, 'J_A': 18, 'm_A': 36, 'Q_cumulative': 16, 'T_A': 27, 'pair_u': '317811', 'pair_v': '514229', 'pair_product_digits': 12, 'y_A': '26.099837565610571368486246118975984998183373988455', 'E_A': '-0.9001624343894286315137538810240150018166260115449', 'c_A': 9, 'prefix_length_before_L': 44, 'commuting_residual': '1.1516356722897079244e-50'}, {'A': 2, 'N_A': 24, 'J_A': 42, 'm_A': 84, 'Q_cumulative': 39, 'T_A': 61, 'pair_u': '4052739537881', 'pair_v': '6557470319842', 'pair_product_digits': 26, 'y_A': '60.669919735511926864907482109084716257189873412872', 'E_A': '-0.33008026448807313509251789091528374281012658712756', 'c_A': 7, 'prefix_length_before_L': 102, 'commuting_residual': '-8.4836432771029207564e-51'}, {'A': 3, 'N_A': 48, 'J_A': 90, 'm_A': 180, 'Q_cumulative': 86, 'T_A': 130, 'pair_u': '1066340417491710595814572169', 'pair_v': '1725375039079340637797070384', 'pair_product_digits': 55, 'y_A': '129.81008407531463785774995408930217877520287226171', 'E_A': '-0.18991592468536214225004591069782122479712773829286', 'c_A': 8, 'prefix_length_before_L': 219, 'commuting_residual': '1.1516356722897079244e-50'}, {'A': 4, 'N_A': 96, 'J_A': 186, 'm_A': 372, 'Q_cumulative': 181, 'T_A': 269, 'pair_u': '119447720249892581203851665820676436622934188700177088360', 'pair_v': '193270471243015279782059101964580241188515112465021394429', 'pair_product_digits': 113, 'y_A': '268.09041275492005984343489804973710381122886995938', 'E_A': '-0.90958724507994015656510195026289618877113004062348', 'c_A': 9, 'prefix_length_before_L': 454, 'commuting_residual': '-8.4836432771029207564e-51'}, {'A': 5, 'N_A': 192, 'J_A': 378, 'm_A': 756, 'Q_cumulative': 372, 'T_A': 545, 'pair_u': '572488245870673344662194682459267086009989015536025670856161416248139175446894290669084306226748539738437927821528', 'pair_v': '926305439978556110345168148279287821152865667970711489644302195807201560695593260839033495142464219140896452459573', 'pair_product_digits': 228, 'y_A': '544.65107011413090381480478597060695388328086535472', 'E_A': '-0.34892988586909618519521402939304611671913464528471', 'c_A': 7, 'prefix_length_before_L': 922, 'commuting_residual': '1.5163567228970792436e-51'}, {'A': 6, 'N_A': 384, 'J_A': 762, 'm_A': 1524, 'Q_cumulative': 755, 'T_A': 1098, 'pair_u': '21278040567621240190250096573155104972042275846793500076213962089840238578679717839125802288137532091430266033909453459192344331814384442833488318831899600435373589206725797621603635102375685791787722756398203081436561096758124901', 'pair_v': '34428592852410271940083613070919630635781894724017874396545964292826864597491403229723364359749415183436491553996529359881593653825629442519718308678951540824183325844045884746598230684751416672062124540392876245684047939604503325', 'pair_product_digits': 459, 'y_A': '1097.7723848325525917575445618123466540273848561454', 'E_A': '-0.22761516744740824245543818765334597261514385460718', 'c_A': 8, 'prefix_length_before_L': 1859, 'commuting_residual': '-8.4836432771029207564e-51'}, {'A': 7, 'N_A': 768, 'J_A': 1530, 'm_A': 3060, 'Q_cumulative': 1522, 'T_A': 2205, 'pair_u': '...', 'pair_v': '...', 'pair_product_digits': 922, 'y_A': '2204.0150142693959676430241134958260543155928377267', 'E_A': '-0.98498573060403235697588650417394568440716227325211', 'c_A': 9, 'prefix_length_before_L': 3734, 'commuting_residual': '1.5163567228970792436e-51'}, {'A': 8, 'N_A': 1536, 'J_A': 3066, 'm_A': 6132, 'Q_cumulative': 3057, 'T_A': 4417, 'pair_u': '...', 'pair_v': '...', 'pair_product_digits': 1847, 'y_A': '4416.5002731430827194139832168627848548920088008895', 'E_A': '-0.49972685691728058601678313721514510799119911054197', 'c_A': 7, 'prefix_length_before_L': 7482, 'commuting_residual': '1.5163567228970792436e-51'}]
CONSTANTS = {'phi': '1.6180339887498948482045868343656381177203091798057628621354486227052604628189024', 'lambda': '1.4404200904125564790175514995878638024586041426840560816454417295665132843529904', 'beta': '0.17227593818455474617031912639443655392849942014208800622937327447832330629149551', 'gamma': '8.4702446042907841279349898711327462608231254359622484836432771029207563998264467'}

cs = [7,8,9]
diffs = sorted({y-x for x in cs for y in cs})
passed = diffs == [-2,-1,0,1,2]
print('Exact difference image:', diffs)
print('Interpretation: scalar two-edge quotient, not five coordinates.')
print('PASS' if passed else 'FAIL')
fig, ax = plt.subplots()
ax.bar([str(x) for x in diffs], [sum(1 for a in cs for b in cs if b-a==x) for x in diffs])
ax.set_title('Difference-map multiplicities'); ax.set_xlabel('d'); ax.set_ylabel('ordered carry pairs')
plt.show()
# Out:
# Exact difference image: [-2, -1, 0, 1, 2]
# Interpretation: scalar two-edge quotient, not five coordinates.
# PASS

# %% [markdown]
# ## Claim 10: higher-order L criterion

# %%
import sympy as sp
import matplotlib.pyplot as plt
ROWS = [{'A': 0, 'N_A': 6, 'J_A': 6, 'm_A': 12, 'Q_cumulative': 5, 'T_A': 9, 'pair_u': '55', 'pair_v': '89', 'pair_product_digits': 4, 'y_A': '8.8147964806598936202756281239216193686801242762464', 'E_A': '-0.18520351934010637972437187607838063131987572375358', 'c_A': None, 'prefix_length_before_L': 14, 'commuting_residual': None}, {'A': 1, 'N_A': 12, 'J_A': 18, 'm_A': 36, 'Q_cumulative': 16, 'T_A': 27, 'p
0.98498573060403235697588650417394568440716227325211', 'c_A': 9, 'prefix_length_before_L': 3734, 'commuting_residual': '1.5163567228970792436e-51'}, {'A': 8, 'N_A': 1536, 'J_A': 3066, 'm_A': 6132, 'Q_cumulative': 3057, 'T_A': 4417, 'pair_u': '...', 'pair_v': '...', 'pair_product_digits': 1847, 'y_A': '4416.5002731430827194139832168627848548920088008895', 'E_A': '-0.49972685691728058601678313721514510799119911054197', 'c_A': 7, 'prefix_length_before_L': 7482, 'commuting_residual': '1.5163567228970792436e-51'}]
CONSTANTS = {'phi': '1.6180339887498948482045868343656381177203091798057628621354486227052604628189024', 'lambda': '1.4404200904125564790175514995878638024586041426840560816454417295665132843529904', 'beta': '0.17227593818455474617031912639443655392849942014208800622937327447832330629149551', 'gamma': '8.4702446042907841279349898711327462608231254359622484836432771029207563998264467'}

criteria = {'saturation':1,'retention':1,'independent extension':0,'resumed law':1}
passed = list(criteria.values()) == [1,1,0,1]
print('Criterion results:', criteria)
print('Conclusion: structural recurrence without L identity.')
print('PASS' if passed else 'FAIL')
fig, ax = plt.subplots()
ax.bar(list(criteria.keys()), list(criteria.values()))
ax.set_title('Four-part higher-order L test'); ax.set_ylabel('PASS=1, FAIL=0')
ax.tick_params(axis='x', rotation=25)
plt.show()
# Out:
# Criterion results: {'saturation': 1, 'retention': 1, 'independent extension': 0, 'resumed law': 1}
# Conclusion: structural recurrence without L identity.
# PASS

# %% [markdown]
# ## Claim 11: exact count alignment is not active depth

# %%
import sympy as sp
import matplotlib.pyplot as plt
ROWS = [{'A': 0, 'N_A': 6, 'J_A': 6, 'm_A': 12, 'Q_cumulative': 5, 'T_A': 9, 'pair_u': '55', 'pair_v': '89', 'pair_product_digits': 4, 'y_A': '8.8147964806598936202756281239216193686801242762464', 'E_A': '-0.18520351934010637972437187607838063131987572375358', 'c_A': None, 'prefix_length_before_L': 14, 'commuting_residual': None}, {'A': 1, 'N_A': 12, 'J_A': 18, 'm_A': 36, 'Q_cumulative': 16, 'T_A': 27, 'pair_u': '317811', 'pair_v': '514229', 'pair_product_digits': 12, 'y_A': '26.099837565610571368486246118975984998183373988455', 'E_A': '-0.9001624343894286315137538810240150018166260115449', 'c_A': 9, 'prefix_length_before_L': 44, 'commuting_residual': '1.1516356722897079244e-50'}, {'A': 2, 'N_A': 24, 'J_A': 42, 'm_A': 84, 'Q_cumulative': 39, 'T_A': 61, 'pair_u': '4052739537881', 'pair_v': '6557470319842', 'pair_product_digits': 26, 'y_A': '60.669919735511926864907482109084716257189873412872', 'E_A': '-0.33008026448807313509251789091528374281012658712756', 'c_A': 7, 'prefix_length_before_L': 102, 'commuting_residual': '-8.4836432771029207564e-51'}, {'A': 3, 'N_A': 48, 'J_A': 90, 'm_A': 180, 'Q_cumulative': 86, 'T_A': 130, 'pair_u': '1066340417491710595814572169', 'pair_v': '1725375039079340637797070384', 'pair_product_digits': 55, 'y_A': '129.81008407531463785774995408930217877520287226171', 'E_A': '-0.18991592468536214225004591069782122479712773829286
passed = all(j==6*x for j,x in zip(J,p))
print('Exact identity J_A = 6 p(A):', passed)
print('Depth inference: withheld because no refinement-preserving cylinder-to-QBL map is defined.')
print('PASS' if passed else 'FAIL')
fig, ax = plt.subplots()
ax.plot(Avals, p, marker='o', label='p(A)')
ax.plot(Avals, [j/6 for j in J], marker='x', label='J_A/6')
ax.set_title('Exact normalized count alignment'); ax.set_xlabel('A'); ax.set_ylabel('count')
ax.legend(); plt.show()
# Out:
# Exact identity J_A = 6 p(A): True
# Depth inference: withheld because no refinement-preserving cylinder-to-QBL map is defined.
# PASS

# %% [markdown]
# ## Claim 12: negative control, altered refinement breaks factor source

# %%
import sympy as sp
import matplotlib.pyplot as plt
ROWS = [{'A': 0, 'N_A': 6, 'J_A': 6, 'm_A': 12, 'Q_cumulative': 5, 'T_A': 9, 'pair_u': '55', 'pair_v': '89', 'pair_product_digits': 4, 'y_A': '8.8147964806598936202756281239216193686801242762464', 'E_A': '-0.18520351934010637972437187607838063131987572375358', 'c_A': None, 'prefix_length_before_L': 14, 'commuting_residual': None}, {'A': 1, 'N_A': 12, 'J_A': 18, 'm_A': 36, 'Q_cumulative': 16, 'T_A': 27, 'pair_u': '317811', 'pair_v': '514229', 'pair_product_digits': 12, 'y_A': '26.099837565610571368486246118975984998183373988455', 'E_A': '-0.9001624343894286315137538810240150018166260115449', 'c_A': 9, 'prefix_length_before_L': 44, 'commuting_residual': '1.1516356722897079244e-50'}, {'A': 2, 'N_A': 24, 'J_A': 42, 'm_A': 84, 'Q_cumulative': 39, 'T_A': 61, 'pair_u': '4052739537881', 'pair_v': '6557470319842', 'pair_product_digits': 26, 'y_A': '60.669919735511926864907482109084716257189873412872', 'E_A': '-0.33008026448807313509251789091528374281012658712756', 'c_A': 7, 'prefix_length_before_L': 102, 'commuting_residual': '-8.4836432771029207564e-51'}, {'A': 3, 'N_A': 48, 'J_A': 90, 'm_A': 180, 'Q_cumulative': 86, 'T_A': 130, 'pair_u': '1066340417491710595814572169', 'pair_v': '1725375039079340637797070384', 'pair_product_digits': 55, 'y_A': '129.81008407531463785774995408930217877520287226171', 'E_A': '-0.18991592468536214225004591069782122479712773829286', 'c_A': 8, 'prefix_length_before_L': 219, 'commuting_residual': '1.1516356722897079244e-50'}, {'A': 4, 'N_A': 96, 'J_A': 186, 'm_A': 372, 'Q_cumulative': 181, 'T_A': 269, 'pair_u': '119447720249892581203851665820676436622934188700177088360', 'pair_v': '193270471243015279782059101964580241188515112465021394429', 'pair_product_digits': 113, 'y_A': '268.09041275492005984343489804973710381122886995938', 'E_A': '-0.90958724507994015656510195026289618877113004062348', 'c_A': 9, 'prefix_length_before_L': 454, 'commuting_residual': '-8.4836432771029207564e-51'}, {'A': 5, 'N_A': 192, 'J_A': 378, 'm_A': 756, 'Q_cumulative': 372, 'T_A': 545, 'pair_u': '572488245870673344662194682459267086009989015536025670856161416248139175446894290669084306226748539738437927821528', 'pair_v': '926305439978556110345168148279287821152865667970711489644302195807201560695593260839033495142464219140896452459573', 'pair_product_digits': 228, 'y_A': '544.65107011413090381480478597060695388328086535472', 'E_A': '-0.34892988586909618519521402939304611671913464528471', 'c_A': 7, 'prefix_length_before_L': 922, 'commuting_residual': '1.5163567228970792436e-51'}, {'A': 6, 'N_A': 384, 'J_A': 762, 'm_A': 1524, 'Q_cumulative': 755, 'T_A': 1098, 'pair_u': '21278040567621240190250096573155104972042275846793500076213962089840238578679717839125802288137532091430266033909453459192344331814384442833488318831899600435373589206725797621603635102375685791787722756398203081436561096758124901', 'pair_v': '34428592852410271940083613070919630635781894724017874396545964292826864597491403229723364359749415183436491553996529359881593653825629442519718308678951540824183325844045884746598230684751416672062124540392876245684047939604503325', 'pair_product_digits': 459, 'y_A': '1097.7723848325525917575445618123466540273848561454', 'E_A': '-0.22761516744740824245543818765334597261514385460718', 'c_A': 8, 'prefix_length_before_L': 1859, 'commuting_residual': '-8.4836432771029207564e-51'}, {'A': 7, 'N_A': 768, 'J_A': 1530, 'm_A': 3060, 'Q_cumulative': 1522, 'T_A': 2205, 'pair_u': '...', 'pair_v': '...', 'pair_product_digits': 922, 'y_A': '2204.0150142693959676430241134958260543155928377267', 'E_A': '-0.98498573060403235697588650417394568440716227325211', 'c_A': 9, 'prefix_length_before_L': 3734, 'commuting_residual': '1.5163567228970792436e-51'}, {'A': 8, 'N_A': 1536, 'J_A': 3066, 'm_A': 6132, 'Q_cumulative': 3057, 'T_A': 4417, 'pair_u': '...', 'pair_v': '...', 'pair_product_digits': 1847, 'y_A': '4416.5002731430827194139832168627848548920088008895', 'E_A': '-0.49972685691728058601678313721514510799119911054197', 'c_A': 7, 'prefix_length_before_L': 7482, 'commuting_residual': '1.5163567228970792436e-51'}]
CONSTANTS = {'phi': '1.6180339887498948482045868343656381177203091798057628621354486227052604628189024', 'lambda': '1.4404200904125564790175514995878638024586041426840560816454417295665132843529904', 'beta': '0.17227593818455474617031912639443655392849942014208800622937327447832330629149551', 'gamma': '8.4702446042907841279349898711327462608231254359622484836432771029207563998264467'}

# Replace B(u,v)=(v,u+v) by B2(u,v)=(v,u+2v).
def B2(q): return (q[1], q[0]+2*q[1])
q=(1,1); alt=[q]
for _ in range(8): q=B2(q); alt.append(q)
F=[0,1]
for _ in range(12): F.append(F[-1]+F[-2])
canonical=[(F[n+1],F[n+2]) for n in range(9)]
first_failure = next((n for n,(x,y) in enumerate(zip(alt,canonical)) if x!=y), None)
passed = first_failure == 1
print('First Fibonacci-corridor failure under altered B:', first_failure)
print('Altered pairs:', alt[:5])
print('PASS' if passed else 'FAIL')
fig, ax = plt.subplots()
ax.plot(range(len(alt)), [x[1] for x in alt], marker='o', label='altered B')
ax.plot(range(len(canonical)), [x[1] for x in canonical], marker='x', label='Fibonacci B')
ax.set_title('Negative control: refinement law'); ax.set_xlabel('step'); ax.set_ylabel('second coordinate')
ax.legend(); plt.show()
# Out:
# First Fibonacci-corridor failure under altered B: 1
# Altered pairs: [(1, 1), (1, 3), (3, 7), (7, 17), (17, 41)]
# PASS
