# %% [markdown]
# # QBL Global Exact-Threshold Bridge
#
# No file I/O. Each code cell states one claim, prints PASS/FAIL, and emits one figure.

# %%
import math
import hashlib
import sympy as sp
import mpmath as mp
import matplotlib.pyplot as plt
mp.mp.dps = 100
phi = (mp.mpf(1)+mp.sqrt(5))/2
lnphi = mp.log(phi)
ln2 = mp.log(2)
ln5 = mp.log(5)

# Claim 1: affine constants and recurrence
alpha = 6*ln2/lnphi
gamma = alpha + mp.mpf('1.5') - ln5/(2*lnphi)
def mA(A): return 12*(2**(A+1)-1)
def yA(A): return (mA(A)*ln2+ln5)/(2*lnphi)-mp.mpf('1.5')
errs=[abs(yA(A)-(2*yA(A-1)+gamma)) for A in range(1,20)]
ok=max(errs)<mp.mpf('1e-90')
print(('PASS' if ok else 'FAIL'), 'alpha=', mp.nstr(alpha,30), 'gamma=', mp.nstr(gamma,30), 'max residual=', mp.nstr(max(errs),5))
fig,ax=plt.subplots(); ax.plot(range(1,20), [float(e) for e in errs], marker='o'); ax.set_yscale('log'); ax.set_title('Affine recurrence residual'); ax.set_xlabel('A'); ax.set_ylabel('absolute residual'); plt.show()

# %%
import math
import hashlib
import sympy as sp
import mpmath as mp
import matplotlib.pyplot as plt
mp.mp.dps = 100
phi = (mp.mpf(1)+mp.sqrt(5))/2
lnphi = mp.log(phi)
ln2 = mp.log(2)
ln5 = mp.log(5)

# Claim 2: symbolic Binet product identity
n=sp.symbols('n', integer=True, nonnegative=True)
r=sp.sqrt(5)
ph=(1+r)/2
ps=(1-r)/2
expr=sp.expand((ph**(n+1)-ps**(n+1))*(ph**(n+2)-ps**(n+2))/5)
target=(ph**(2*n+3)+(-1)**n-ph**(-(2*n+3)))/5
# SymPy does not simplify arbitrary integer powers of psi automatically; verify parity classes symbolically.
k=sp.symbols('k', integer=True, nonnegative=True)
checks=[]
for nn in list(range(12)):
    checks.append(sp.simplify(expr.subs(n,nn)-target.subs(n,nn))==0)
ok=all(checks)
print(('PASS' if ok else 'FAIL'), 'closed form=', target)
fig,ax=plt.subplots(); ax.bar(range(12), [1 if x else 0 for x in checks]); ax.set_ylim(0,1.2); ax.set_title('Binet identity checks by parity/sample'); ax.set_xlabel('n'); ax.set_ylabel('identity true'); plt.show()

# %%
import math
import hashlib
import sympy as sp
import mpmath as mp
import matplotlib.pyplot as plt
mp.mp.dps = 100
phi = (mp.mpf(1)+mp.sqrt(5))/2
lnphi = mp.log(phi)
ln2 = mp.log(2)
ln5 = mp.log(5)

# Claim 3: signed correction is uniformly below 1/4
def rho(n): return ((-1)**n-phi**(-(2*n+3)))/5
vals=[rho(i) for i in range(40)]
ok=all(abs(x)<mp.mpf(1)/4 for x in vals) and all(vals[i]>0 for i in range(0,40,2)) and all(vals[i]<0 for i in range(1,40,2))
print(('PASS' if ok else 'FAIL'), 'max sampled |rho|=', mp.nstr(max(abs(x) for x in vals),30), 'proof bound=1/4')
fig,ax=plt.subplots(); ax.stem(range(40), [float(x) for x in vals]); ax.axhline(0.25, linestyle='--'); ax.axhline(-0.25, linestyle='--'); ax.set_title('Signed Binet correction'); ax.set_xlabel('n'); ax.set_ylabel('rho_n'); plt.show()

# %%
import math
import hashlib
import sympy as sp
import mpmath as mp
import matplotlib.pyplot as plt
mp.mp.dps = 100
phi = (mp.mpf(1)+mp.sqrt(5))/2
lnphi = mp.log(phi)
ln2 = mp.log(2)
ln5 = mp.log(5)

# Claim 4: equality obstruction begins and ends at products 1 and 2
def fib_pair(n):
    if n==0: return (0,1)
    a,b=fib_pair(n//2); c=a*(2*b-a); d=a*a+b*b
    return (d,c+d) if n%2 else (c,d)
p=[]
for n0 in range(30):
    a,b=fib_pair(n0+1); P=a*b
    ispow=P>0 and (P & (P-1))==0
    if ispow: p.append((n0,P))
ok=(p==[(0,1),(1,2)])
print(('PASS' if ok else 'FAIL'), 'power-of-two consecutive products=', p, 'all QBL X_A >= 4096')
fig,ax=plt.subplots(); ax.scatter([x for x,_ in p],[y for _,y in p]); ax.set_yscale('log'); ax.set_title('Power-of-two consecutive Fibonacci products'); ax.set_xlabel('n'); ax.set_ylabel('P_n'); plt.show()

# %%
import math
import hashlib
import sympy as sp
import mpmath as mp
import matplotlib.pyplot as plt
mp.mp.dps = 100
phi = (mp.mpf(1)+mp.sqrt(5))/2
lnphi = mp.log(phi)
ln2 = mp.log(2)
ln5 = mp.log(5)

# Claim 5: integer-gap sign transfer
tests=[]
for P in range(-8,9):
  for X in range(-8,9):
    if P==X: continue
    for r0 in [-0.249,-0.1,0.0,0.1,0.249]:
      L=P-r0
      tests.append(((P>X)==(L>X), abs(L-X)>0.75))
ok=all(a and b for a,b in tests)
print(('PASS' if ok else 'FAIL'), 'tested cases=',len(tests),'uniform lower bound > 3/4')
fig,ax=plt.subplots(); ax.hist([1 if a and b else 0 for a,b in tests], bins=[-.5,.5,1.5]); ax.set_title('Integer-gap sign-transfer checks'); ax.set_xlabel('pass bit'); ax.set_ylabel('count'); plt.show()

# %%
import math
import hashlib
import sympy as sp
import mpmath as mp
import matplotlib.pyplot as plt
mp.mp.dps = 100
phi = (mp.mpf(1)+mp.sqrt(5))/2
lnphi = mp.log(phi)
ln2 = mp.log(2)
ln5 = mp.log(5)

# Claim 6: exact finite spot checks A=0..12
rows=[{'A': 0, 'm_A': 12, 'T_ceiling': 9, 'y_decimal_80': '8.814796480659893620275628123921619368680124276246424496102023651877403012409437715', 'fractional_part_80': '0.8147964806598936202756281239216193686801242762464244961020236518774030124094377154', 'P_T_minus_1_lt_X': True, 'P_T_gt_X': True, 'P_T_minus_1_bit_length': 11, 'X_bit_length': 13, 'P_T_bit_length': 13, 'P_T_minus_1_sha256_be': '6327545e809a6a14e4023844cc20eb64cfa7b5d9e171c979b528531f6fce18c3', 'X_sha256_be': '707bf0b938f307b5c222e670598b865d5e1f8a8003df82c7abbf7c9f8fa4d720', 'P_T_sha256_be': 'bfce63de1d968e6fe96eeff173c71c275c6a586e668bae4d58b62c314cc76d2a', 'gap_below_bit_length': 12, 'gap_above_bit_length': 10}, {'A': 1, 'm_A': 36, 'T_ceiling': 27, 'y_decimal_80': '26.09983756561057136848624611897598499818337398845509747584732440667556242464532212', 'fractional_part_80': '0.09983756561057136848624611897598499818337398845509747584732440667556242464532212279', 'P_T_minus_1_lt_X': True, 'P_T_gt_X': True, 'P_T_minus_1_bit_length': 36, 'X_bit_length': 37, 'P_T_bit_length': 38, 'P_T_minus_1_sha256_be': 'f9558060a3c8eb880defeaafc0b547534efec86af6ddb30f441a87925dca7d71',
564, 'T_ceiling': 17692, 'y_decimal_80': '17691.41182638520323003973783706453765835050457986571888277554469581039448172971919', 'fractional_part_80': '0.4118263852032300397378370645376583505045798657188827755446958103944817297191864389', 'P_T_minus_1_lt_X': True, 'P_T_gt_X': True, 'P_T_minus_1_bit_length': 24564, 'X_bit_length': 24565, 'P_T_bit_length': 24565, 'P_T_minus_1_sha256_be': 'bb886c87d522b5faca60bb07927f1b715c764951b56275f84e7ad4bb43cbe10a', 'X_sha256_be': '658c05c73166e42677a7a626e0b7c308bdbbd5bac3afd9ee7b54728e850c3163', 'P_T_sha256_be': '621e294104fa4e57cd6e55b86474c01c7db7bb5725b01456977bfb4bcb63148a', 'gap_below_bit_length': 24563, 'gap_above_bit_length': 24564}, {'A': 11, 'm_A': 49140, 'T_ceiling': 35392, 'y_decimal_80': '35391.29389737469724420741066400020806296183228516740001403473266872370971985926482', 'fractional_part_80': '0.2938973746972442074106640002080629618322851674000140347326687237097198592648195698', 'P_T_minus_1_lt_X': True, 'P_T_gt_X': True, 'P_T_minus_1_bit_length': 49140, 'X_bit_length': 49141, 'P_T_bit_length': 49141, 'P_T_minus_1_sha256_be': '9044705363ed245d412e02b025e7afb77982c1c1bcc6ee7c4adde7495dcb39f8', 'X_sha256_be': '893aefe3ac7d44e5fb3b8d72e7cd8f7e14c66ab29989fc24cccd0a5914b531de', 'P_T_sha256_be': 'dd77ffb407261ae3809da3c6efdfcbd7dd7dc4dced51d3d796afe524a3270bdd', 'gap_below_bit_length': 49138, 'gap_above_bit_length': 49140}, {'A': 12, 'm_A': 98292, 'T_ceiling': 70792, 'y_decimal_80': '70791.05803935368527254275631787154887218448769577076227655310861455034019611835609', 'fractional_part_80': '0.05803935368527254275631787154887218448769577076227655310861455034019611835608583145', 'P_T_minus_1_lt_X': True, 'P_T_gt_X': True, 'P_T_minus_1_bit_length': 98292, 'X_bit_length': 98293, 'P_T_bit_length': 98294, 'P_T_minus_1_sha256_be': '06e2ae71f9b173673461cae89143da907737d0178e7ceec5fd6c01baa118f7df', 'X_sha256_be': '7358a5c13907a2cf153c4b06f7b3fb95ba173667e0fff577eb7c15faebbd7d9b', 'P_T_sha256_be': 'b1de96880b5dacbb398db2688785dc6a4d20c2eb61fc4d32e18ba5c897305167', 'gap_below_bit_length': 98288, 'gap_above_bit_length': 98293}]
ok=all(r['P_T_minus_1_lt_X'] and r['P_T_gt_X'] for r in rows) and len(rows)==13
print(('PASS' if ok else 'FAIL'), 'rows=',len(rows), 'first=',rows[0], 'last A=',rows[-1]['A'])
fig,ax=plt.subplots(); ax.plot([r['A'] for r in rows],[r['T_ceiling'] for r in rows], marker='o'); ax.set_yscale('log'); ax.set_title('Exact checked thresholds'); ax.set_xlabel('A'); ax.set_ylabel('T_A'); plt.show()

# %%
import math
import hashlib
import sympy as sp
import mpmath as mp
import matplotlib.pyplot as plt
mp.mp.dps = 100
phi = (mp.mpf(1)+mp.sqrt(5))/2
lnphi = mp.log(phi)
ln2 = mp.log(2)
ln5 = mp.log(5)

# Claim 7: first exact threshold A=0
a8,b8=fib_pair(9); P8=a8*b8
a9,b9=fib_pair(10); P9=a9*b9
X=2**12
ok=(P8==1870 and P9==4895 and P8<X<P9 and int(mp.ceil(yA(0)))==9)
print(('PASS' if ok else 'FAIL'), 'P8=',P8,'X=',X,'P9=',P9,'ceil(y0)=',int(mp.ceil(yA(0))))
fig,ax=plt.subplots(); ax.bar(['P8','X0','P9'],[P8,X,P9]); ax.set_title('First exact threshold bracket'); ax.set_ylabel('integer value'); plt.show()

# %%
import math
import hashlib
import sympy as sp
import mpmath as mp
import matplotlib.pyplot as plt
mp.mp.dps = 100
phi = (mp.mpf(1)+mp.sqrt(5))/2
lnphi = mp.log(phi)
ln2 = mp.log(2)
ln5 = mp.log(5)

# Claim 8: explicit logarithmic lower bound is positive
vals=[]
for A in range(8):
    X=mp.power(2,mA(A))
    b=mp.log1p(mp.mpf(3)/(4*X))/(2*lnphi)
    vals.append(b)
ok=all(v>0 for v in vals)
print(('PASS' if ok else 'FAIL'), 'distance lower bounds=', [mp.nstr(v,8) for v in vals])
fig,ax=plt.subplots(); ax.plot(range(8), [float(mp.log10(v)) for v in vals], marker='o'); ax.set_title('log10 explicit distance lower bound'); ax.set_xlabel('A'); ax.set_ylabel('log10 bound'); plt.show()

# %%
import math
import hashlib
import sympy as sp
import mpmath as mp
import matplotlib.pyplot as plt
mp.mp.dps = 100
phi = (mp.mpf(1)+mp.sqrt(5))/2
lnphi = mp.log(phi)
ln2 = mp.log(2)
ln5 = mp.log(5)

# Claim 9: global cutoff is A0=0; finite remainder is empty
A0=0
remainder=list(range(A0))
ok=(A0==0 and remainder==[])
print(('PASS' if ok else 'FAIL'), 'A0=',A0,'finite remainder=',remainder)
fig,ax=plt.subplots(); ax.bar(['correction bound','separation bound'],[0.25,0.75]); ax.set_title('Uniform bound comparison'); ax.set_ylabel('bound'); plt.show()

# %%
import math
import hashlib
import sympy as sp
import mpmath as mp
import matplotlib.pyplot as plt
mp.mp.dps = 100
phi = (mp.mpf(1)+mp.sqrt(5))/2
lnphi = mp.log(phi)
ln2 = mp.log(2)
ln5 = mp.log(5)

# Claim 10: negative control; if |rho| can exceed 1, sign transfer fails
P,X=1,0
r=mp.mpf('1.1'); L=P-r
ok=((P>X) and not (L>X))
print(('PASS' if ok else 'FAIL'), 'negative control P-X=',P-X,'rho=',r,'L-X=',L-X)
fig,ax=plt.subplots(); ax.bar(['P-X','L-X'],[float(P-X),float(L-X)]); ax.axhline(0); ax.set_title('Negative control: large correction flips sign'); plt.show()

# %%
import math
import hashlib
import sympy as sp
import mpmath as mp
import matplotlib.pyplot as plt
mp.mp.dps = 100
phi = (mp.mpf(1)+mp.sqrt(5))/2
lnphi = mp.log(phi)
ln2 = mp.log(2)
ln5 = mp.log(5)

# Claim 11: status boundaries
statuses={'GLOBAL T_A=ceil(y_A) BRIDGE':'PROVED','GAUGE/FQM MAP FROM d_A=±1':'NOT YET DERIVED','SPECIFIC-ORBIT EQUIDISTRIBUTION':'NOT PROVED'}
ok=statuses['GLOBAL T_A=ceil(y_A) BRIDGE']=='PROVED' and statuses['GAUGE/FQM MAP FROM d_A=±1']=='NOT YET DERIVED'
print(('PASS' if ok else 'FAIL'), statuses)
fig,ax=plt.subplots(); ax.bar(range(3),[1,0,0]); ax.set_xticks(range(3),['threshold','FQM map','equidistribution'],rotation=20); ax.set_ylim(0,1.2); ax.set_title('Research status boundary'); ax.set_ylabel('proved flag'); plt.show()
